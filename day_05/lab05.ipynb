# %% [markdown]
# 1. Build Identity Block
#
# 2. Build Convolutional Block
#
# 3. Build ResNet50
#
# 4. Build ResNet on CIFAR10
#
# 4. Train ResNet on CIFAR10
#
# 5. Generalize ResNet

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import (Input, Conv2D, Activation, 
                                     BatchNormalization, Add,
                                     ZeroPadding2D, MaxPooling2D,
                                     GlobalAveragePooling2D,
                                     Dense, Flatten)
from tensorflow.keras import Model

# %% [markdown]
# # 1. Build Identity Block

# %%
def identity_block(X, filters):
    F1, F2, F3 = filters

    shortcut = X

    # Conv 1x1
    X = Conv2D(filters=F1, kernel_size=1)(X)
    X = BatchNormalization()(X)
    X = Activation('relu')(X)

    # Conv 3x3
    X = Conv2D(filters=F2, kernel_size=3, padding='same')(X)
    X = BatchNormalization()(X)
    X = Activation('relu')(X)

    # Conv 1x1
    X = Conv2D(filters=F3, kernel_size=1)(X)
    X = BatchNormalization()(X)

    # Shortcut
    if F3 != F2:
        shortcut = Conv2D(filters=F3, kernel_size=1)(shortcut)
    X = Add()([shortcut, X])
    X = Activation('relu')(X)

    return X

# %%
# Test out function
input = Input(shape=(32, 32, 16))
output = identity_block(input, filters=[16, 16, 16])

model = Model(inputs=input, outputs=output)
model.summary()
# Out:
# Model: "model_15"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_20 (InputLayer)       [(None, 32, 32, 16)]         0         []
#
#  conv2d_327 (Conv2D)         (None, 32, 32, 16)           272       ['input_20[0][0]']
#
#  batch_normalization_289 (B  (None, 32, 32, 16)           64        ['conv2d_327[0][0]']
#  atchNormalization)
#
#  activation_344 (Activation  (None, 32, 32, 16)           0         ['batch_normalization_289[0][0
#  )                                                                  ]']
#
#  conv2d_328 (Conv2D)         (None, 32, 32, 16)           2320      ['activation_344[0][0]']
#
#  batch_normalization_290 (B  (None, 32, 32, 16)           64        ['conv2d_328[0][0]']
#  atchNormalization)
#
#  activation_345 (Activation  (None, 32, 32, 16)           0         ['batch_normalization_290[0][0
#  )                                                                  ]']
#
#  conv2d_329 (Conv2D)         (None, 32, 32, 16)           272       ['activation_345[0][0]']
#
#  batch_normalization_291 (B  (None, 32, 32, 16)           64        ['conv2d_329[0][0]']
#  atchNormalization)
#
#  add_86 (Add)                (None, 32, 32, 16)           0         ['input_20[0][0]',
#                                                                      'batch_normalization_291[0][0
#                                                                     ]']
#
#  activation_346 (Activation  (None, 32, 32, 16)           0         ['add_86[0][0]']
#  )
#
# ==================================================================================================
# Total params: 3056 (11.94 KB)
# Trainable params: 2960 (11.56 KB)
# Non-trainable params: 96 (384.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# # 2. Build Convolutional Block

# %%
def convolutional_block(X, filters, s=2):
    F1, F2, F3 = filters

    shortcut = X 

    # Conv 1x1
    X = Conv2D(filters=F1, kernel_size=1)(X)
    X = BatchNormalization()(X)
    X = Activation('relu')(X)

    # Conv 3x3
    X = Conv2D(filters=F2, kernel_size=3, strides=s, padding='same')(X)
    X = BatchNormalization()(X)
    X = Activation('relu')(X)

    # Conv 1x1
    X = Conv2D(filters=F3, kernel_size=1)(X)
    X = BatchNormalization()(X)

    # Convolutional shortcut
    shortcut = Conv2D(filters=F3, kernel_size=1, strides=s)(shortcut)
    shortcut = BatchNormalization()(shortcut)

    # Shortcut
    X = Add()([shortcut, X])
    X = Activation('relu')(X)

    return X

# %%
input = Input(shape=(32, 32, 16))
output = convolutional_block(input, filters=[16, 16, 16])

model = Model(inputs=input, outputs=output)
model.summary()
# Out:
# Model: "model_16"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_21 (InputLayer)       [(None, 32, 32, 16)]         0         []
#
#  conv2d_330 (Conv2D)         (None, 32, 32, 16)           272       ['input_21[0][0]']
#
#  batch_normalization_292 (B  (None, 32, 32, 16)           64        ['conv2d_330[0][0]']
#  atchNormalization)
#
#  activation_347 (Activation  (None, 32, 32, 16)           0         ['batch_normalization_292[0][0
#  )                                                                  ]']
#
#  conv2d_331 (Conv2D)         (None, 16, 16, 16)           2320      ['activation_347[0][0]']
#
#  batch_normalization_293 (B  (None, 16, 16, 16)           64        ['conv2d_331[0][0]']
#  atchNormalization)
#
#  activation_348 (Activation  (None, 16, 16, 16)           0         ['batch_normalization_293[0][0
#  )                                                                  ]']
#
#  conv2d_333 (Conv2D)         (None, 16, 16, 16)           272       ['input_21[0][0]']
#
#  conv2d_332 (Conv2D)         (None, 16, 16, 16)           272       ['activation_348[0][0]']
#
#  batch_normalization_295 (B  (None, 16, 16, 16)           64        ['conv2d_333[0][0]']
#  atchNormalization)
#
#  batch_normalization_294 (B  (None, 16, 16, 16)           64        ['conv2d_332[0][0]']
#  atchNormalization)
#
#  add_87 (Add)                (None, 16, 16, 16)           0         ['batch_normalization_295[0][0
#                                                                     ]',
#                                                                      'batch_normalization_294[0][0
#                                                                     ]']
#
#  activation_349 (Activation  (None, 16, 16, 16)           0         ['add_87[0][0]']
#  )
#
# ==================================================================================================
# Total params: 3392 (13.25 KB)
# Trainable params: 3264 (12.75 KB)
# Non-trainable params: 128 (512.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# # 3. Build ResNet50

# %%
def ResNet50(input_shape=(224, 224, 3), num_classes=1000):
    input = Input(input_shape)

    # Zero-padding
    X = ZeroPadding2D((3, 3))(input)

    # Stage 01
    X = Conv2D(filters=64, kernel_size=7, strides=2, activation='relu')(X)
    X = BatchNormalization()(X)
    X = MaxPooling2D(3, strides=2, padding='same')(X)

    # Stage 02
    for _ in range(3):
        X = identity_block(X, filters=[64, 64, 256])
    
    # Stage 03
    X = convolutional_block(X, filters=[128, 128, 512], s=2)
    for _ in range(3):
        X = identity_block(X, filters=[128, 128, 512])
        
    # Stage 04
    X = convolutional_block(X, filters=[256, 256, 1024], s=2)
    for _ in range(5):
        X = identity_block(X, filters=[256, 256, 1024])

    # Stage 05
    X = convolutional_block(X, filters=[512, 512, 2048], s=2)
    for _ in range(2):
        X = identity_block(X, filters=[512, 512, 2048])

    X = GlobalAveragePooling2D()(X)

    # Ouput layer
    X = Flatten()(X)
    X = Dense(units=num_classes, activation='softmax')(X)

    # Create model
    model = Model(inputs=input, outputs=X)

    return model

# %%
model = ResNet50()
model.summary()
# Out:
# Model: "model_17"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_22 (InputLayer)       [(None, 224, 224, 3)]        0         []
#
#  zero_padding2d_10 (ZeroPad  (None, 230, 230, 3)          0         ['input_22[0][0]']
#  ding2D)
#
#  conv2d_334 (Conv2D)         (None, 112, 112, 64)         9472      ['zero_padding2d_10[0][0]']
#
#  batch_normalization_296 (B  (None, 112, 112, 64)         256       ['conv2d_334[0][0]']
#  atchNormalization)
#
#  max_pooling2d_9 (MaxPoolin  (None, 56, 56, 64)           0         ['batch_normalization_296[0][0
#  g2D)                                                               ]']
#
#  conv2d_335 (Conv2D)         (None, 56, 56, 64)           4160      ['max_pooling2d_9[0][0]']
#
#  batch_normalization_297 (B  (None, 56, 56, 64)           256       ['conv2d_335[0][0]']
#  atchNormalization)
#
#  activation_350 (Activation  (None, 56, 56, 64)           0         ['batch_normalization_297[0][0
#  )                                                                  ]']
#
#  conv2d_336 (Conv2D)         (None, 56, 56, 64)           36928     ['activation_350[0][0]']
#
#  batch_normalization_298 (B  (None, 56, 56, 64)           256       ['conv2d_336[0][0]']
#  atchNormalization)
#
#  activation_351 (Activation  (None, 56, 56, 64)           0         ['batch_normalization_298[0][0
#  )                                                                  ]']
#
#  conv2d_337 (Conv2D)         (None, 56, 56, 256)          16640     ['activation_351[0][0]']
#
#  conv2d_338 (Conv2D)         (None, 56, 56, 256)          16640     ['max_pooling2d_9[0][0]']
#
#  batch_normalization_299 (B  (None, 56, 56, 256)          1024      ['conv2d_337[0][0]']
#  atchNormalization)
#
#  add_88 (Add)                (None, 56, 56, 256)          0         ['conv2d_338[0][0]',
#                                                                      'batch_normalization_299[0][0
#                                                                     ]']
#
#  activation_352 (Activation  (None, 56, 56, 256)          0         ['add_88[0][0]']
#  )
#
#  conv2d_339 (Conv2D)         (None, 56, 56, 64)           16448     ['activation_352[0][0]']
#
#  batch_normalization_300 (B  (None, 56, 56, 64)           256       ['conv2d_339[0][0]']
#  atchNormalization)
#
#  activation_353 (Activation  (None, 56, 56, 64)           0         ['batch_normalization_300[0][0
#  )                                                                  ]']
#
#  conv2d_340 (Conv2D)         (None, 56, 56, 64)           36928     ['activation_353[0][0]']
#
#  batch_normalization_301 (B  (None, 56, 56, 64)           256       ['conv2d_340[0][0]']
#  atchNormalization)
#
#  activation_354 (Activation  (None, 56, 56, 64)           0         ['batch_normalization_301[0][0
#  )                                                                  ]']
#
#  conv2d_341 (Conv2D)         (None, 56, 56, 256)          16640     ['activation_354[0][0]']
#
#  conv2d_342 (Conv2D)         (None, 56, 56, 256)          65792     ['activation_352[0][0]']
#
#  batch_normalization_302 (B  (None, 56, 56, 256)          1024      ['conv2d_341[0][0]']
#  atchNormalization)
#
#  add_89 (Add)                (None, 56, 56, 256)          0         ['conv2d_342[0][0]',
#                                                                      'batch_normalization_302[0][0
#                                                                     ]']
#
#  activation_355 (Activation  (None, 56, 56, 256)          0         ['add_89[0][0]']
#  )
#
#  conv2d_343 (Conv2D)         (None, 56, 56, 64)           16448     ['activation_355[0][0]']
#
#  batch_normalization_303 (B  (None, 56, 56, 64)           256       ['conv2d_343[0][0]']
#  atchNormalization)
#
#  activation_356 (Activation  (None, 56, 56, 64)           0         ['batch_normalization_303[0][0
#  )                                                                  ]']
#
#  conv2d_344 (Conv2D)         (None, 56, 56, 64)           36928     ['activation_356[0][0]']
#
#  batch_normalization_304 (B  (None, 56, 56, 64)           256       ['conv2d_344[0][0]']
#  atchNormalization)
#
#  activation_357 (Activation  (None, 56, 56, 64)           0         ['batch_normalization_304[0][0
#  )                                                                  ]']
#
#  conv2d_345 (Conv2D)         (None, 56, 56, 256)          16640     ['activation_357[0][0]']
#
#  conv2d_346 (Conv2D)         (None, 56, 56, 256)          65792     ['activation_355[0][0]']
#
#  batch_normalization_305 (B  (None, 56, 56, 256)          1024      ['conv2d_345[0][0]']
#  atchNormalization)
#
#  add_90 (Add)                (None, 56, 56, 256)          0         ['conv2d_346[0][0]',
#                                                                      'batch_normalization_305[0][0
#                                                                     ]']
#
#  activation_358 (Activation  (None, 56, 56, 256)          0         ['add_90[0][0]']
#  )
#
#  conv2d_347 (Conv2D)         (None, 56, 56, 128)          32896     ['activation_358[0][0]']
#
#  batch_normalization_306 (B  (None, 56, 56, 128)          512       ['conv2d_347[0][0]']
#  atchNormalization)
#
#  activation_359 (Activation  (None, 56, 56, 128)          0         ['batch_normalization_306[0][0
#  )                                                                  ]']
#
#  conv2d_348 (Conv2D)         (None, 28, 28, 128)          147584    ['activation_359[0][0]']
#
#  batch_normalization_307 (B  (None, 28, 28, 128)          512       ['conv2d_348[0][0]']
#  atchNormalization)
#
#  activation_360 (Activation  (None, 28, 28, 128)          0         ['batch_normalization_307[0][0
#  )                                                                  ]']
#
#  conv2d_350 (Conv2D)         (None, 28, 28, 512)          131584    ['activation_358[0][0]']
#
#  conv2d_349 (Conv2D)         (None, 28, 28, 512)          66048     ['activation_360[0][0]']
#
#  batch_normalization_309 (B  (None, 28, 28, 512)          2048      ['conv2d_350[0][0]']
#  atchNormalization)
#
#  batch_normalization_308 (B  (None, 28, 28, 512)          2048      ['conv2d_349[0][0]']
#  atchNormalization)
#
#  add_91 (Add)                (None, 28, 28, 512)          0         ['batch_normalization_309[0][0
#                                                                     ]',
#                                                                      'batch_normalization_308[0][0
#                                                                     ]']
#
#  activation_361 (Activation  (None, 28, 28, 512)          0         ['add_91[0][0]']
#  )
#
#  conv2d_351 (Conv2D)         (None, 28, 28, 128)          65664     ['activation_361[0][0]']
#
#  batch_normalization_310 (B  (None, 28, 28, 128)          512       ['conv2d_351[0][0]']
#  atchNormalization)
#
#  activation_362 (Activation  (None, 28, 28, 128)          0         ['batch_normalization_310[0][0
#  )                                                                  ]']
#
#  conv2d_352 (Conv2D)         (None, 28, 28, 128)          147584    ['activation_362[0][0]']
#
#  batch_normalization_311 (B  (None, 28, 28, 128)          512       ['conv2d_352[0][0]']
#  atchNormalization)
#
#  activation_363 (Activation  (None, 28, 28, 128)          0         ['batch_normalization_311[0][0
#  )                                                                  ]']
#
#  conv2d_353 (Conv2D)         (None, 28, 28, 512)          66048     ['activation_363[0][0]']
#
#  conv2d_354 (Conv2D)         (None, 28, 28, 512)          262656    ['activation_361[0][0]']
#
#  batch_normalization_312 (B  (None, 28, 28, 512)          2048      ['conv2d_353[0][0]']
#  atchNormalization)
#
#  add_92 (Add)                (None, 28, 28, 512)          0         ['conv2d_354[0][0]',
#                                                                      'batch_normalization_312[0][0
#                                                                     ]']
#
#  activation_364 (Activation  (None, 28, 28, 512)          0         ['add_92[0][0]']
#  )
#
#  conv2d_355 (Conv2D)         (None, 28, 28, 128)          65664     ['activation_364[0][0]']
#
#  batch_normalization_313 (B  (None, 28, 28, 128)          512       ['conv2d_355[0][0]']
#  atchNormalization)
#
#  activation_365 (Activation  (None, 28, 28, 128)          0         ['batch_normalization_313[0][0
#  )                                                                  ]']
#
#  conv2d_356 (Conv2D)         (None, 28, 28, 128)          147584    ['activation_365[0][0]']
#
#  batch_normalization_314 (B  (None, 28, 28, 128)          512       ['conv2d_356[0][0]']
#  atchNormalization)
#
#  activation_366 (Activation  (None, 28, 28, 128)          0         ['batch_normalization_314[0][0
#  )                                                                  ]']
#
#  conv2d_357 (Conv2D)         (None, 28, 28, 512)          66048     ['activation_366[0][0]']
#
#  conv2d_358 (Conv2D)         (None, 28, 28, 512)          262656    ['activation_364[0][0]']
#
#  batch_normalization_315 (B  (None, 28, 28, 512)          2048      ['conv2d_357[0][0]']
#  atchNormalization)
#
#  add_93 (Add)                (None, 28, 28, 512)          0         ['conv2d_358[0][0]',
#                                                                      'batch_normalization_315[0][0
#                                                                     ]']
#
#  activation_367 (Activation  (None, 28, 28, 512)          0         ['add_93[0][0]']
#  )
#
#  conv2d_359 (Conv2D)         (None, 28, 28, 128)          65664     ['activation_367[0][0]']
#
#  batch_normalization_316 (B  (None, 28, 28, 128)          512       ['conv2d_359[0][0]']
#  atchNormalization)
#
#  activation_368 (Activation  (None, 28, 28, 128)          0         ['batch_normalization_316[0][0
#  )                                                                  ]']
#
#  conv2d_360 (Conv2D)         (None, 28, 28, 128)          147584    ['activation_368[0][0]']
#
#  batch_normalization_317 (B  (None, 28, 28, 128)          512       ['conv2d_360[0][0]']
#  atchNormalization)
#
#  activation_369 (Activation  (None, 28, 28, 128)          0         ['batch_normalization_317[0][0
#  )                                                                  ]']
#
#  conv2d_361 (Conv2D)         (None, 28, 28, 512)          66048     ['activation_369[0][0]']
#
#  conv2d_362 (Conv2D)         (None, 28, 28, 512)          262656    ['activation_367[0][0]']
#
#  batch_normalization_318 (B  (None, 28, 28, 512)          2048      ['conv2d_361[0][0]']
#  atchNormalization)
#
#  add_94 (Add)                (None, 28, 28, 512)          0         ['conv2d_362[0][0]',
#                                                                      'batch_normalization_318[0][0
#                                                                     ]']
#
#  activation_370 (Activation  (None, 28, 28, 512)          0         ['add_94[0][0]']
#  )
#
#  conv2d_363 (Conv2D)         (None, 28, 28, 256)          131328    ['activation_370[0][0]']
#
#  batch_normalization_319 (B  (None, 28, 28, 256)          1024      ['conv2d_363[0][0]']
#  atchNormalization)
#
#  activation_371 (Activation  (None, 28, 28, 256)          0         ['batch_normalization_319[0][0
#  )                                                                  ]']
#
#  conv2d_364 (Conv2D)         (None, 14, 14, 256)          590080    ['activation_371[0][0]']
#
#  batch_normalization_320 (B  (None, 14, 14, 256)          1024      ['conv2d_364[0][0]']
#  atchNormalization)
#
#  activation_372 (Activation  (None, 14, 14, 256)          0         ['batch_normalization_320[0][0
#  )                                                                  ]']
#
#  conv2d_366 (Conv2D)         (None, 14, 14, 1024)         525312    ['activation_370[0][0]']
#
#  conv2d_365 (Conv2D)         (None, 14, 14, 1024)         263168    ['activation_372[0][0]']
#
#  batch_normalization_322 (B  (None, 14, 14, 1024)         4096      ['conv2d_366[0][0]']
#  atchNormalization)
#
#  batch_normalization_321 (B  (None, 14, 14, 1024)         4096      ['conv2d_365[0][0]']
#  atchNormalization)
#
#  add_95 (Add)                (None, 14, 14, 1024)         0         ['batch_normalization_322[0][0
#                                                                     ]',
#                                                                      'batch_normalization_321[0][0
#                                                                     ]']
#
#  activation_373 (Activation  (None, 14, 14, 1024)         0         ['add_95[0][0]']
#  )
#
#  conv2d_367 (Conv2D)         (None, 14, 14, 256)          262400    ['activation_373[0][0]']
#
#  batch_normalization_323 (B  (None, 14, 14, 256)          1024      ['conv2d_367[0][0]']
#  atchNormalization)
#
#  activation_374 (Activation  (None, 14, 14, 256)          0         ['batch_normalization_323[0][0
#  )                                                                  ]']
#
#  conv2d_368 (Conv2D)         (None, 14, 14, 256)          590080    ['activation_374[0][0]']
#
#  batch_normalization_324 (B  (None, 14, 14, 256)          1024      ['conv2d_368[0][0]']
#  atchNormalization)
#
#  activation_375 (Activation  (None, 14, 14, 256)          0         ['batch_normalization_324[0][0
#  )                                                                  ]']
#
#  conv2d_369 (Conv2D)         (None, 14, 14, 1024)         263168    ['activation_375[0][0]']
#
#  conv2d_370 (Conv2D)         (None, 14, 14, 1024)         1049600   ['activation_373[0][0]']
#
#  batch_normalization_325 (B  (None, 14, 14, 1024)         4096      ['conv2d_369[0][0]']
#  atchNormalization)
#
#  add_96 (Add)                (None, 14, 14, 1024)         0         ['conv2d_370[0][0]',
#                                                                      'batch_normalization_325[0][0
#                                                                     ]']
#
#  activation_376 (Activation  (None, 14, 14, 1024)         0         ['add_96[0][0]']
#  )
#
#  conv2d_371 (Conv2D)         (None, 14, 14, 256)          262400    ['activation_376[0][0]']
#
#  batch_normalization_326 (B  (None, 14, 14, 256)          1024      ['conv2d_371[0][0]']
#  atchNormalization)
#
#  activation_377 (Activation  (None, 14, 14, 256)          0         ['batch_normalization_326[0][0
#  )                                                                  ]']
#
#  conv2d_372 (Conv2D)         (None, 14, 14, 256)          590080    ['activation_377[0][0]']
#
#  batch_normalization_327 (B  (None, 14, 14, 256)          1024      ['conv2d_372[0][0]']
#  atchNormalization)
#
#  activation_378 (Activation  (None, 14, 14, 256)          0         ['batch_normalization_327[0][0
#  )                                                                  ]']
#
#  conv2d_373 (Conv2D)         (None, 14, 14, 1024)         263168    ['activation_378[0][0]']
#
#  conv2d_374 (Conv2D)         (None, 14, 14, 1024)         1049600   ['activation_376[0][0]']
#
#  batch_normalization_328 (B  (None, 14, 14, 1024)         4096      ['conv2d_373[0][0]']
#  atchNormalization)
#
#  add_97 (Add)                (None, 14, 14, 1024)         0         ['conv2d_374[0][0]',
#                                                                      'batch_normalization_328[0][0
#                                                                     ]']
#
#  activation_379 (Activation  (None, 14, 14, 1024)         0         ['add_97[0][0]']
#  )
#
#  conv2d_375 (Conv2D)         (None, 14, 14, 256)          262400    ['activation_379[0][0]']
#
#  batch_normalization_329 (B  (None, 14, 14, 256)          1024      ['conv2d_375[0][0]']
#  atchNormalization)
#
#  activation_380 (Activation  (None, 14, 14, 256)          0         ['batch_normalization_329[0][0
#  )                                                                  ]']
#
#  conv2d_376 (Conv2D)         (None, 14, 14, 256)          590080    ['activation_380[0][0]']
#
#  batch_normalization_330 (B  (None, 14, 14, 256)          1024      ['conv2d_376[0][0]']
#  atchNormalization)
#
#  activation_381 (Activation  (None, 14, 14, 256)          0         ['batch_normalization_330[0][0
#  )                                                                  ]']
#
#  conv2d_377 (Conv2D)         (None, 14, 14, 1024)         263168    ['activation_381[0][0]']
#
#  conv2d_378 (Conv2D)         (None, 14, 14, 1024)         1049600   ['activation_379[0][0]']
#
#  batch_normalization_331 (B  (None, 14, 14, 1024)         4096      ['conv2d_377[0][0]']
#  atchNormalization)
#
#  add_98 (Add)                (None, 14, 14, 1024)         0         ['conv2d_378[0][0]',
#                                                                      'batch_normalization_331[0][0
#                                                                     ]']
#
#  activation_382 (Activation  (None, 14, 14, 1024)         0         ['add_98[0][0]']
#  )
#
#  conv2d_379 (Conv2D)         (None, 14, 14, 256)          262400    ['activation_382[0][0]']
#
#  batch_normalization_332 (B  (None, 14, 14, 256)          1024      ['conv2d_379[0][0]']
#  atchNormalization)
#
#  activation_383 (Activation  (None, 14, 14, 256)          0         ['batch_normalization_332[0][0
#  )                                                                  ]']
#
#  conv2d_380 (Conv2D)         (None, 14, 14, 256)          590080    ['activation_383[0][0]']
#
#  batch_normalization_333 (B  (None, 14, 14, 256)          1024      ['conv2d_380[0][0]']
#  atchNormalization)
#
#  activation_384 (Activation  (None, 14, 14, 256)          0         ['batch_normalization_333[0][0
#  )                                                                  ]']
#
#  conv2d_381 (Conv2D)         (None, 14, 14, 1024)         263168    ['activation_384[0][0]']
#
#  conv2d_382 (Conv2D)         (None, 14, 14, 1024)         1049600   ['activation_382[0][0]']
#
#  batch_normalization_334 (B  (None, 14, 14, 1024)         4096      ['conv2d_381[0][0]']
#  atchNormalization)
#
#  add_99 (Add)                (None, 14, 14, 1024)         0         ['conv2d_382[0][0]',
#                                                                      'batch_normalization_334[0][0
#                                                                     ]']
#
#  activation_385 (Activation  (None, 14, 14, 1024)         0         ['add_99[0][0]']
#  )
#
#  conv2d_383 (Conv2D)         (None, 14, 14, 256)          262400    ['activation_385[0][0]']
#
#  batch_normalization_335 (B  (None, 14, 14, 256)          1024      ['conv2d_383[0][0]']
#  atchNormalization)
#
#  activation_386 (Activation  (None, 14, 14, 256)          0         ['batch_normalization_335[0][0
#  )                                                                  ]']
#
#  conv2d_384 (Conv2D)         (None, 14, 14, 256)          590080    ['activation_386[0][0]']
#
#  batch_normalization_336 (B  (None, 14, 14, 256)          1024      ['conv2d_384[0][0]']
#  atchNormalization)
#
#  activation_387 (Activation  (None, 14, 14, 256)          0         ['batch_normalization_336[0][0
#  )                                                                  ]']
#
#  conv2d_385 (Conv2D)         (None, 14, 14, 1024)         263168    ['activation_387[0][0]']
#
#  conv2d_386 (Conv2D)         (None, 14, 14, 1024)         1049600   ['activation_385[0][0]']
#
#  batch_normalization_337 (B  (None, 14, 14, 1024)         4096      ['conv2d_385[0][0]']
#  atchNormalization)
#
#  add_100 (Add)               (None, 14, 14, 1024)         0         ['conv2d_386[0][0]',
#                                                                      'batch_normalization_337[0][0
#                                                                     ]']
#
#  activation_388 (Activation  (None, 14, 14, 1024)         0         ['add_100[0][0]']
#  )
#
#  conv2d_387 (Conv2D)         (None, 14, 14, 512)          524800    ['activation_388[0][0]']
#
#  batch_normalization_338 (B  (None, 14, 14, 512)          2048      ['conv2d_387[0][0]']
#  atchNormalization)
#
#  activation_389 (Activation  (None, 14, 14, 512)          0         ['batch_normalization_338[0][0
#  )                                                                  ]']
#
#  conv2d_388 (Conv2D)         (None, 7, 7, 512)            2359808   ['activation_389[0][0]']
#
#  batch_normalization_339 (B  (None, 7, 7, 512)            2048      ['conv2d_388[0][0]']
#  atchNormalization)
#
#  activation_390 (Activation  (None, 7, 7, 512)            0         ['batch_normalization_339[0][0
#  )                                                                  ]']
#
#  conv2d_390 (Conv2D)         (None, 7, 7, 2048)           2099200   ['activation_388[0][0]']
#
#  conv2d_389 (Conv2D)         (None, 7, 7, 2048)           1050624   ['activation_390[0][0]']
#
#  batch_normalization_341 (B  (None, 7, 7, 2048)           8192      ['conv2d_390[0][0]']
#  atchNormalization)
#
#  batch_normalization_340 (B  (None, 7, 7, 2048)           8192      ['conv2d_389[0][0]']
#  atchNormalization)
#
#  add_101 (Add)               (None, 7, 7, 2048)           0         ['batch_normalization_341[0][0
#                                                                     ]',
#                                                                      'batch_normalization_340[0][0
#                                                                     ]']
#
#  activation_391 (Activation  (None, 7, 7, 2048)           0         ['add_101[0][0]']
#  )
#
#  conv2d_391 (Conv2D)         (None, 7, 7, 512)            1049088   ['activation_391[0][0]']
#
#  batch_normalization_342 (B  (None, 7, 7, 512)            2048      ['conv2d_391[0][0]']
#  atchNormalization)
#
#  activation_392 (Activation  (None, 7, 7, 512)            0         ['batch_normalization_342[0][0
#  )                                                                  ]']
#
#  conv2d_392 (Conv2D)         (None, 7, 7, 512)            2359808   ['activation_392[0][0]']
#
#  batch_normalization_343 (B  (None, 7, 7, 512)            2048      ['conv2d_392[0][0]']
#  atchNormalization)
#
#  activation_393 (Activation  (None, 7, 7, 512)            0         ['batch_normalization_343[0][0
#  )                                                                  ]']
#
#  conv2d_393 (Conv2D)         (None, 7, 7, 2048)           1050624   ['activation_393[0][0]']
#
#  conv2d_394 (Conv2D)         (None, 7, 7, 2048)           4196352   ['activation_391[0][0]']
#
#  batch_normalization_344 (B  (None, 7, 7, 2048)           8192      ['conv2d_393[0][0]']
#  atchNormalization)
#
#  add_102 (Add)               (None, 7, 7, 2048)           0         ['conv2d_394[0][0]',
#                                                                      'batch_normalization_344[0][0
#                                                                     ]']
#
#  activation_394 (Activation  (None, 7, 7, 2048)           0         ['add_102[0][0]']
#  )
#
#  conv2d_395 (Conv2D)         (None, 7, 7, 512)            1049088   ['activation_394[0][0]']
#
#  batch_normalization_345 (B  (None, 7, 7, 512)            2048      ['conv2d_395[0][0]']
#  atchNormalization)
#
#  activation_395 (Activation  (None, 7, 7, 512)            0         ['batch_normalization_345[0][0
#  )                                                                  ]']
#
#  conv2d_396 (Conv2D)         (None, 7, 7, 512)            2359808   ['activation_395[0][0]']
#
#  batch_normalization_346 (B  (None, 7, 7, 512)            2048      ['conv2d_396[0][0]']
#  atchNormalization)
#
#  activation_396 (Activation  (None, 7, 7, 512)            0         ['batch_normalization_346[0][0
#  )                                                                  ]']
#
#  conv2d_397 (Conv2D)         (None, 7, 7, 2048)           1050624   ['activation_396[0][0]']
#
#  conv2d_398 (Conv2D)         (None, 7, 7, 2048)           4196352   ['activation_394[0][0]']
#
#  batch_normalization_347 (B  (None, 7, 7, 2048)           8192      ['conv2d_397[0][0]']
#  atchNormalization)
#
#  add_103 (Add)               (None, 7, 7, 2048)           0         ['conv2d_398[0][0]',
#                                                                      'batch_normalization_347[0][0
#                                                                     ]']
#
#  activation_397 (Activation  (None, 7, 7, 2048)           0         ['add_103[0][0]']
#  )
#
#  global_average_pooling2d_2  (None, 2048)                 0         ['activation_397[0][0]']
#   (GlobalAveragePooling2D)
#
#  flatten_2 (Flatten)         (None, 2048)                 0         ['global_average_pooling2d_2[0
#                                                                     ][0]']
#
#  dense_2 (Dense)             (None, 1000)                 2049000   ['flatten_2[0][0]']
#
# ==================================================================================================
# Total params: 40195944 (153.34 MB)
# Trainable params: 40143336 (153.13 MB)
# Non-trainable params: 52608 (205.50 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# # 4. Build ResNet on CIFAR10

# %%
def ResNet_Cifar10(input_shape=(32, 32, 3), num_classes=10):
    input = Input(input_shape)

    # Stage 1
    X = Conv2D(filters=64, kernel_size=3, padding='same')(input)
    X = BatchNormalization(axis=3)(X)
    X = Activation('relu')(X)

    # Stage 2
    for _ in range(3):
        X = identity_block(X, filters=[16, 16, 64])

    # Stage 3
    X = convolutional_block(X, filters=[32, 32, 128], s=2)
    for _ in range(6):
        X = identity_block(X, filters=[32, 32, 128])
    
    # Stage 4
    X = convolutional_block(X, filters=[64, 64, 256], s=2)
    for _ in range(3):
        X = identity_block(X, filters=[64, 64, 256])

    X = GlobalAveragePooling2D()(X)
    X = Flatten()(X)

    # Output
    X = Dense(units=num_classes, activation='softmax')(X)

    model = Model(inputs=input, outputs=X)

    return model

# %%
model = ResNet_Cifar10(input_shape=(32, 32, 3), num_classes=10)
model.summary()
# Out:
# Model: "model_19"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_24 (InputLayer)       [(None, 32, 32, 3)]          0         []
#
#  conv2d_456 (Conv2D)         (None, 32, 32, 64)           1792      ['input_24[0][0]']
#
#  batch_normalization_393 (B  (None, 32, 32, 64)           256       ['conv2d_456[0][0]']
#  atchNormalization)
#
#  activation_441 (Activation  (None, 32, 32, 64)           0         ['batch_normalization_393[0][0
#  )                                                                  ]']
#
#  conv2d_457 (Conv2D)         (None, 32, 32, 16)           1040      ['activation_441[0][0]']
#
#  batch_normalization_394 (B  (None, 32, 32, 16)           64        ['conv2d_457[0][0]']
#  atchNormalization)
#
#  activation_442 (Activation  (None, 32, 32, 16)           0         ['batch_normalization_394[0][0
#  )                                                                  ]']
#
#  conv2d_458 (Conv2D)         (None, 32, 32, 16)           2320      ['activation_442[0][0]']
#
#  batch_normalization_395 (B  (None, 32, 32, 16)           64        ['conv2d_458[0][0]']
#  atchNormalization)
#
#  activation_443 (Activation  (None, 32, 32, 16)           0         ['batch_normalization_395[0][0
#  )                                                                  ]']
#
#  conv2d_459 (Conv2D)         (None, 32, 32, 64)           1088      ['activation_443[0][0]']
#
#  conv2d_460 (Conv2D)         (None, 32, 32, 64)           4160      ['activation_441[0][0]']
#
#  batch_normalization_396 (B  (None, 32, 32, 64)           256       ['conv2d_459[0][0]']
#  atchNormalization)
#
#  add_118 (Add)               (None, 32, 32, 64)           0         ['conv2d_460[0][0]',
#                                                                      'batch_normalization_396[0][0
#                                                                     ]']
#
#  activation_444 (Activation  (None, 32, 32, 64)           0         ['add_118[0][0]']
#  )
#
#  conv2d_461 (Conv2D)         (None, 32, 32, 16)           1040      ['activation_444[0][0]']
#
#  batch_normalization_397 (B  (None, 32, 32, 16)           64        ['conv2d_461[0][0]']
#  atchNormalization)
#
#  activation_445 (Activation  (None, 32, 32, 16)           0         ['batch_normalization_397[0][0
#  )                                                                  ]']
#
#  conv2d_462 (Conv2D)         (None, 32, 32, 16)           2320      ['activation_445[0][0]']
#
#  batch_normalization_398 (B  (None, 32, 32, 16)           64        ['conv2d_462[0][0]']
#  atchNormalization)
#
#  activation_446 (Activation  (None, 32, 32, 16)           0         ['batch_normalization_398[0][0
#  )                                                                  ]']
#
#  conv2d_463 (Conv2D)         (None, 32, 32, 64)           1088      ['activation_446[0][0]']
#
#  conv2d_464 (Conv2D)         (None, 32, 32, 64)           4160      ['activation_444[0][0]']
#
#  batch_normalization_399 (B  (None, 32, 32, 64)           256       ['conv2d_463[0][0]']
#  atchNormalization)
#
#  add_119 (Add)               (None, 32, 32, 64)           0         ['conv2d_464[0][0]',
#                                                                      'batch_normalization_399[0][0
#                                                                     ]']
#
#  activation_447 (Activation  (None, 32, 32, 64)           0         ['add_119[0][0]']
#  )
#
#  conv2d_465 (Conv2D)         (None, 32, 32, 16)           1040      ['activation_447[0][0]']
#
#  batch_normalization_400 (B  (None, 32, 32, 16)           64        ['conv2d_465[0][0]']
#  atchNormalization)
#
#  activation_448 (Activation  (None, 32, 32, 16)           0         ['batch_normalization_400[0][0
#  )                                                                  ]']
#
#  conv2d_466 (Conv2D)         (None, 32, 32, 16)           2320      ['activation_448[0][0]']
#
#  batch_normalization_401 (B  (None, 32, 32, 16)           64        ['conv2d_466[0][0]']
#  atchNormalization)
#
#  activation_449 (Activation  (None, 32, 32, 16)           0         ['batch_normalization_401[0][0
#  )                                                                  ]']
#
#  conv2d_467 (Conv2D)         (None, 32, 32, 64)           1088      ['activation_449[0][0]']
#
#  conv2d_468 (Conv2D)         (None, 32, 32, 64)           4160      ['activation_447[0][0]']
#
#  batch_normalization_402 (B  (None, 32, 32, 64)           256       ['conv2d_467[0][0]']
#  atchNormalization)
#
#  add_120 (Add)               (None, 32, 32, 64)           0         ['conv2d_468[0][0]',
#                                                                      'batch_normalization_402[0][0
#                                                                     ]']
#
#  activation_450 (Activation  (None, 32, 32, 64)           0         ['add_120[0][0]']
#  )
#
#  conv2d_469 (Conv2D)         (None, 32, 32, 32)           2080      ['activation_450[0][0]']
#
#  batch_normalization_403 (B  (None, 32, 32, 32)           128       ['conv2d_469[0][0]']
#  atchNormalization)
#
#  activation_451 (Activation  (None, 32, 32, 32)           0         ['batch_normalization_403[0][0
#  )                                                                  ]']
#
#  conv2d_470 (Conv2D)         (None, 16, 16, 32)           9248      ['activation_451[0][0]']
#
#  batch_normalization_404 (B  (None, 16, 16, 32)           128       ['conv2d_470[0][0]']
#  atchNormalization)
#
#  activation_452 (Activation  (None, 16, 16, 32)           0         ['batch_normalization_404[0][0
#  )                                                                  ]']
#
#  conv2d_472 (Conv2D)         (None, 16, 16, 128)          8320      ['activation_450[0][0]']
#
#  conv2d_471 (Conv2D)         (None, 16, 16, 128)          4224      ['activation_452[0][0]']
#
#  batch_normalization_406 (B  (None, 16, 16, 128)          512       ['conv2d_472[0][0]']
#  atchNormalization)
#
#  batch_normalization_405 (B  (None, 16, 16, 128)          512       ['conv2d_471[0][0]']
#  atchNormalization)
#
#  add_121 (Add)               (None, 16, 16, 128)          0         ['batch_normalization_406[0][0
#                                                                     ]',
#                                                                      'batch_normalization_405[0][0
#                                                                     ]']
#
#  activation_453 (Activation  (None, 16, 16, 128)          0         ['add_121[0][0]']
#  )
#
#  conv2d_473 (Conv2D)         (None, 16, 16, 32)           4128      ['activation_453[0][0]']
#
#  batch_normalization_407 (B  (None, 16, 16, 32)           128       ['conv2d_473[0][0]']
#  atchNormalization)
#
#  activation_454 (Activation  (None, 16, 16, 32)           0         ['batch_normalization_407[0][0
#  )                                                                  ]']
#
#  conv2d_474 (Conv2D)         (None, 16, 16, 32)           9248      ['activation_454[0][0]']
#
#  batch_normalization_408 (B  (None, 16, 16, 32)           128       ['conv2d_474[0][0]']
#  atchNormalization)
#
#  activation_455 (Activation  (None, 16, 16, 32)           0         ['batch_normalization_408[0][0
#  )                                                                  ]']
#
#  conv2d_475 (Conv2D)         (None, 16, 16, 128)          4224      ['activation_455[0][0]']
#
#  conv2d_476 (Conv2D)         (None, 16, 16, 128)          16512     ['activation_453[0][0]']
#
#  batch_normalization_409 (B  (None, 16, 16, 128)          512       ['conv2d_475[0][0]']
#  atchNormalization)
#
#  add_122 (Add)               (None, 16, 16, 128)          0         ['conv2d_476[0][0]',
#                                                                      'batch_normalization_409[0][0
#                                                                     ]']
#
#  activation_456 (Activation  (None, 16, 16, 128)          0         ['add_122[0][0]']
#  )
#
#  conv2d_477 (Conv2D)         (None, 16, 16, 32)           4128      ['activation_456[0][0]']
#
#  batch_normalization_410 (B  (None, 16, 16, 32)           128       ['conv2d_477[0][0]']
#  atchNormalization)
#
#  activation_457 (Activation  (None, 16, 16, 32)           0         ['batch_normalization_410[0][0
#  )                                                                  ]']
#
#  conv2d_478 (Conv2D)         (None, 16, 16, 32)           9248      ['activation_457[0][0]']
#
#  batch_normalization_411 (B  (None, 16, 16, 32)           128       ['conv2d_478[0][0]']
#  atchNormalization)
#
#  activation_458 (Activation  (None, 16, 16, 32)           0         ['batch_normalization_411[0][0
#  )                                                                  ]']
#
#  conv2d_479 (Conv2D)         (None, 16, 16, 128)          4224      ['activation_458[0][0]']
#
#  conv2d_480 (Conv2D)         (None, 16, 16, 128)          16512     ['activation_456[0][0]']
#
#  batch_normalization_412 (B  (None, 16, 16, 128)          512       ['conv2d_479[0][0]']
#  atchNormalization)
#
#  add_123 (Add)               (None, 16, 16, 128)          0         ['conv2d_480[0][0]',
#                                                                      'batch_normalization_412[0][0
#                                                                     ]']
#
#  activation_459 (Activation  (None, 16, 16, 128)          0         ['add_123[0][0]']
#  )
#
#  conv2d_481 (Conv2D)         (None, 16, 16, 32)           4128      ['activation_459[0][0]']
#
#  batch_normalization_413 (B  (None, 16, 16, 32)           128       ['conv2d_481[0][0]']
#  atchNormalization)
#
#  activation_460 (Activation  (None, 16, 16, 32)           0         ['batch_normalization_413[0][0
#  )                                                                  ]']
#
#  conv2d_482 (Conv2D)         (None, 16, 16, 32)           9248      ['activation_460[0][0]']
#
#  batch_normalization_414 (B  (None, 16, 16, 32)           128       ['conv2d_482[0][0]']
#  atchNormalization)
#
#  activation_461 (Activation  (None, 16, 16, 32)           0         ['batch_normalization_414[0][0
#  )                                                                  ]']
#
#  conv2d_483 (Conv2D)         (None, 16, 16, 128)          4224      ['activation_461[0][0]']
#
#  conv2d_484 (Conv2D)         (None, 16, 16, 128)          16512     ['activation_459[0][0]']
#
#  batch_normalization_415 (B  (None, 16, 16, 128)          512       ['conv2d_483[0][0]']
#  atchNormalization)
#
#  add_124 (Add)               (None, 16, 16, 128)          0         ['conv2d_484[0][0]',
#                                                                      'batch_normalization_415[0][0
#                                                                     ]']
#
#  activation_462 (Activation  (None, 16, 16, 128)          0         ['add_124[0][0]']
#  )
#
#  conv2d_485 (Conv2D)         (None, 16, 16, 32)           4128      ['activation_462[0][0]']
#
#  batch_normalization_416 (B  (None, 16, 16, 32)           128       ['conv2d_485[0][0]']
#  atchNormalization)
#
#  activation_463 (Activation  (None, 16, 16, 32)           0         ['batch_normalization_416[0][0
#  )                                                                  ]']
#
#  conv2d_486 (Conv2D)         (None, 16, 16, 32)           9248      ['activation_463[0][0]']
#
#  batch_normalization_417 (B  (None, 16, 16, 32)           128       ['conv2d_486[0][0]']
#  atchNormalization)
#
#  activation_464 (Activation  (None, 16, 16, 32)           0         ['batch_normalization_417[0][0
#  )                                                                  ]']
#
#  conv2d_487 (Conv2D)         (None, 16, 16, 128)          4224      ['activation_464[0][0]']
#
#  conv2d_488 (Conv2D)         (None, 16, 16, 128)          16512     ['activation_462[0][0]']
#
#  batch_normalization_418 (B  (None, 16, 16, 128)          512       ['conv2d_487[0][0]']
#  atchNormalization)
#
#  add_125 (Add)               (None, 16, 16, 128)          0         ['conv2d_488[0][0]',
#                                                                      'batch_normalization_418[0][0
#                                                                     ]']
#
#  activation_465 (Activation  (None, 16, 16, 128)          0         ['add_125[0][0]']
#  )
#
#  conv2d_489 (Conv2D)         (None, 16, 16, 32)           4128      ['activation_465[0][0]']
#
#  batch_normalization_419 (B  (None, 16, 16, 32)           128       ['conv2d_489[0][0]']
#  atchNormalization)
#
#  activation_466 (Activation  (None, 16, 16, 32)           0         ['batch_normalization_419[0][0
#  )                                                                  ]']
#
#  conv2d_490 (Conv2D)         (None, 16, 16, 32)           9248      ['activation_466[0][0]']
#
#  batch_normalization_420 (B  (None, 16, 16, 32)           128       ['conv2d_490[0][0]']
#  atchNormalization)
#
#  activation_467 (Activation  (None, 16, 16, 32)           0         ['batch_normalization_420[0][0
#  )                                                                  ]']
#
#  conv2d_491 (Conv2D)         (None, 16, 16, 128)          4224      ['activation_467[0][0]']
#
#  conv2d_492 (Conv2D)         (None, 16, 16, 128)          16512     ['activation_465[0][0]']
#
#  batch_normalization_421 (B  (None, 16, 16, 128)          512       ['conv2d_491[0][0]']
#  atchNormalization)
#
#  add_126 (Add)               (None, 16, 16, 128)          0         ['conv2d_492[0][0]',
#                                                                      'batch_normalization_421[0][0
#                                                                     ]']
#
#  activation_468 (Activation  (None, 16, 16, 128)          0         ['add_126[0][0]']
#  )
#
#  conv2d_493 (Conv2D)         (None, 16, 16, 32)           4128      ['activation_468[0][0]']
#
#  batch_normalization_422 (B  (None, 16, 16, 32)           128       ['conv2d_493[0][0]']
#  atchNormalization)
#
#  activation_469 (Activation  (None, 16, 16, 32)           0         ['batch_normalization_422[0][0
#  )                                                                  ]']
#
#  conv2d_494 (Conv2D)         (None, 16, 16, 32)           9248      ['activation_469[0][0]']
#
#  batch_normalization_423 (B  (None, 16, 16, 32)           128       ['conv2d_494[0][0]']
#  atchNormalization)
#
#  activation_470 (Activation  (None, 16, 16, 32)           0         ['batch_normalization_423[0][0
#  )                                                                  ]']
#
#  conv2d_495 (Conv2D)         (None, 16, 16, 128)          4224      ['activation_470[0][0]']
#
#  conv2d_496 (Conv2D)         (None, 16, 16, 128)          16512     ['activation_468[0][0]']
#
#  batch_normalization_424 (B  (None, 16, 16, 128)          512       ['conv2d_495[0][0]']
#  atchNormalization)
#
#  add_127 (Add)               (None, 16, 16, 128)          0         ['conv2d_496[0][0]',
#                                                                      'batch_normalization_424[0][0
#                                                                     ]']
#
#  activation_471 (Activation  (None, 16, 16, 128)          0         ['add_127[0][0]']
#  )
#
#  conv2d_497 (Conv2D)         (None, 16, 16, 64)           8256      ['activation_471[0][0]']
#
#  batch_normalization_425 (B  (None, 16, 16, 64)           256       ['conv2d_497[0][0]']
#  atchNormalization)
#
#  activation_472 (Activation  (None, 16, 16, 64)           0         ['batch_normalization_425[0][0
#  )                                                                  ]']
#
#  conv2d_498 (Conv2D)         (None, 8, 8, 64)             36928     ['activation_472[0][0]']
#
#  batch_normalization_426 (B  (None, 8, 8, 64)             256       ['conv2d_498[0][0]']
#  atchNormalization)
#
#  activation_473 (Activation  (None, 8, 8, 64)             0         ['batch_normalization_426[0][0
#  )                                                                  ]']
#
#  conv2d_500 (Conv2D)         (None, 8, 8, 256)            33024     ['activation_471[0][0]']
#
#  conv2d_499 (Conv2D)         (None, 8, 8, 256)            16640     ['activation_473[0][0]']
#
#  batch_normalization_428 (B  (None, 8, 8, 256)            1024      ['conv2d_500[0][0]']
#  atchNormalization)
#
#  batch_normalization_427 (B  (None, 8, 8, 256)            1024      ['conv2d_499[0][0]']
#  atchNormalization)
#
#  add_128 (Add)               (None, 8, 8, 256)            0         ['batch_normalization_428[0][0
#                                                                     ]',
#                                                                      'batch_normalization_427[0][0
#                                                                     ]']
#
#  activation_474 (Activation  (None, 8, 8, 256)            0         ['add_128[0][0]']
#  )
#
#  conv2d_501 (Conv2D)         (None, 8, 8, 64)             16448     ['activation_474[0][0]']
#
#  batch_normalization_429 (B  (None, 8, 8, 64)             256       ['conv2d_501[0][0]']
#  atchNormalization)
#
#  activation_475 (Activation  (None, 8, 8, 64)             0         ['batch_normalization_429[0][0
#  )                                                                  ]']
#
#  conv2d_502 (Conv2D)         (None, 8, 8, 64)             36928     ['activation_475[0][0]']
#
#  batch_normalization_430 (B  (None, 8, 8, 64)             256       ['conv2d_502[0][0]']
#  atchNormalization)
#
#  activation_476 (Activation  (None, 8, 8, 64)             0         ['batch_normalization_430[0][0
#  )                                                                  ]']
#
#  conv2d_503 (Conv2D)         (None, 8, 8, 256)            16640     ['activation_476[0][0]']
#
#  conv2d_504 (Conv2D)         (None, 8, 8, 256)            65792     ['activation_474[0][0]']
#
#  batch_normalization_431 (B  (None, 8, 8, 256)            1024      ['conv2d_503[0][0]']
#  atchNormalization)
#
#  add_129 (Add)               (None, 8, 8, 256)            0         ['conv2d_504[0][0]',
#                                                                      'batch_normalization_431[0][0
#                                                                     ]']
#
#  activation_477 (Activation  (None, 8, 8, 256)            0         ['add_129[0][0]']
#  )
#
#  conv2d_505 (Conv2D)         (None, 8, 8, 64)             16448     ['activation_477[0][0]']
#
#  batch_normalization_432 (B  (None, 8, 8, 64)             256       ['conv2d_505[0][0]']
#  atchNormalization)
#
#  activation_478 (Activation  (None, 8, 8, 64)             0         ['batch_normalization_432[0][0
#  )                                                                  ]']
#
#  conv2d_506 (Conv2D)         (None, 8, 8, 64)             36928     ['activation_478[0][0]']
#
#  batch_normalization_433 (B  (None, 8, 8, 64)             256       ['conv2d_506[0][0]']
#  atchNormalization)
#
#  activation_479 (Activation  (None, 8, 8, 64)             0         ['batch_normalization_433[0][0
#  )                                                                  ]']
#
#  conv2d_507 (Conv2D)         (None, 8, 8, 256)            16640     ['activation_479[0][0]']
#
#  conv2d_508 (Conv2D)         (None, 8, 8, 256)            65792     ['activation_477[0][0]']
#
#  batch_normalization_434 (B  (None, 8, 8, 256)            1024      ['conv2d_507[0][0]']
#  atchNormalization)
#
#  add_130 (Add)               (None, 8, 8, 256)            0         ['conv2d_508[0][0]',
#                                                                      'batch_normalization_434[0][0
#                                                                     ]']
#
#  activation_480 (Activation  (None, 8, 8, 256)            0         ['add_130[0][0]']
#  )
#
#  conv2d_509 (Conv2D)         (None, 8, 8, 64)             16448     ['activation_480[0][0]']
#
#  batch_normalization_435 (B  (None, 8, 8, 64)             256       ['conv2d_509[0][0]']
#  atchNormalization)
#
#  activation_481 (Activation  (None, 8, 8, 64)             0         ['batch_normalization_435[0][0
#  )                                                                  ]']
#
#  conv2d_510 (Conv2D)         (None, 8, 8, 64)             36928     ['activation_481[0][0]']
#
#  batch_normalization_436 (B  (None, 8, 8, 64)             256       ['conv2d_510[0][0]']
#  atchNormalization)
#
#  activation_482 (Activation  (None, 8, 8, 64)             0         ['batch_normalization_436[0][0
#  )                                                                  ]']
#
#  conv2d_511 (Conv2D)         (None, 8, 8, 256)            16640     ['activation_482[0][0]']
#
#  conv2d_512 (Conv2D)         (None, 8, 8, 256)            65792     ['activation_480[0][0]']
#
#  batch_normalization_437 (B  (None, 8, 8, 256)            1024      ['conv2d_511[0][0]']
#  atchNormalization)
#
#  add_131 (Add)               (None, 8, 8, 256)            0         ['conv2d_512[0][0]',
#                                                                      'batch_normalization_437[0][0
#                                                                     ]']
#
#  activation_483 (Activation  (None, 8, 8, 256)            0         ['add_131[0][0]']
#  )
#
#  global_average_pooling2d_4  (None, 256)                  0         ['activation_483[0][0]']
#   (GlobalAveragePooling2D)
#
#  flatten_4 (Flatten)         (None, 256)                  0         ['global_average_pooling2d_4[0
#                                                                     ][0]']
#
#  dense_4 (Dense)             (None, 10)                   2570      ['flatten_4[0][0]']
#
# ==================================================================================================
# Total params: 775466 (2.96 MB)
# Trainable params: 768234 (2.93 MB)
# Non-trainable params: 7232 (28.25 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# # 5. Generalize ResNet

# %%
def ResNet(input_shape=(224, 224, 3), num_classes=1000, stages=[3, 4, 6, 3], filters=[64, 256, 512, 1024, 2048]):
    input = Input(input_shape)

    # Stage 01
    X = Conv2D(filters=filters[0], kernel_size=7, strides=2, activation='relu')(input)
    X = BatchNormalization()(X)
    X = MaxPooling2D(3, strides=2, padding='same')(X)

    # Stage 02 -> 05
    for stage, filter in zip(stages, filters[1:]):
        filters_in_stage = [int(filter / 4), int(filter / 4), filter]
        for i in range(stage):
            if i == 0:
                X = convolutional_block(X, filters=filters_in_stage)
            else:
                X = identity_block(X, filters=filters_in_stage)
    
    X = GlobalAveragePooling2D()(X)

    # Output layer
    X = Flatten()(X)
    X = Dense(units=num_classes, activation='softmax')(X)

    model = Model(inputs=input, outputs=X)

    return model

# %%
# ResNet50
model50 = ResNet(input_shape=(224, 224, 3), num_classes=1000, 
                 stages=[3,4,6,3], filters=[64,256,512,1024,2048])
model50.summary()
# Out:
# Model: "model_20"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_26 (InputLayer)       [(None, 224, 224, 3)]        0         []
#
#  conv2d_514 (Conv2D)         (None, 109, 109, 64)         9472      ['input_26[0][0]']
#
#  batch_normalization_438 (B  (None, 109, 109, 64)         256       ['conv2d_514[0][0]']
#  atchNormalization)
#
#  max_pooling2d_10 (MaxPooli  (None, 55, 55, 64)           0         ['batch_normalization_438[0][0
#  ng2D)                                                              ]']
#
#  conv2d_515 (Conv2D)         (None, 55, 55, 64)           4160      ['max_pooling2d_10[0][0]']
#
#  batch_normalization_439 (B  (None, 55, 55, 64)           256       ['conv2d_515[0][0]']
#  atchNormalization)
#
#  activation_484 (Activation  (None, 55, 55, 64)           0         ['batch_normalization_439[0][0
#  )                                                                  ]']
#
#  conv2d_516 (Conv2D)         (None, 28, 28, 64)           36928     ['activation_484[0][0]']
#
#  batch_normalization_440 (B  (None, 28, 28, 64)           256       ['conv2d_516[0][0]']
#  atchNormalization)
#
#  activation_485 (Activation  (None, 28, 28, 64)           0         ['batch_normalization_440[0][0
#  )                                                                  ]']
#
#  conv2d_518 (Conv2D)         (None, 28, 28, 256)          16640     ['max_pooling2d_10[0][0]']
#
#  conv2d_517 (Conv2D)         (None, 28, 28, 256)          16640     ['activation_485[0][0]']
#
#  batch_normalization_442 (B  (None, 28, 28, 256)          1024      ['conv2d_518[0][0]']
#  atchNormalization)
#
#  batch_normalization_441 (B  (None, 28, 28, 256)          1024      ['conv2d_517[0][0]']
#  atchNormalization)
#
#  add_132 (Add)               (None, 28, 28, 256)          0         ['batch_normalization_442[0][0
#                                                                     ]',
#                                                                      'batch_normalization_441[0][0
#                                                                     ]']
#
#  activation_486 (Activation  (None, 28, 28, 256)          0         ['add_132[0][0]']
#  )
#
#  conv2d_519 (Conv2D)         (None, 28, 28, 64)           16448     ['activation_486[0][0]']
#
#  batch_normalization_443 (B  (None, 28, 28, 64)           256       ['conv2d_519[0][0]']
#  atchNormalization)
#
#  activation_487 (Activation  (None, 28, 28, 64)           0         ['batch_normalization_443[0][0
#  )                                                                  ]']
#
#  conv2d_520 (Conv2D)         (None, 28, 28, 64)           36928     ['activation_487[0][0]']
#
#  batch_normalization_444 (B  (None, 28, 28, 64)           256       ['conv2d_520[0][0]']
#  atchNormalization)
#
#  activation_488 (Activation  (None, 28, 28, 64)           0         ['batch_normalization_444[0][0
#  )                                                                  ]']
#
#  conv2d_521 (Conv2D)         (None, 28, 28, 256)          16640     ['activation_488[0][0]']
#
#  conv2d_522 (Conv2D)         (None, 28, 28, 256)          65792     ['activation_486[0][0]']
#
#  batch_normalization_445 (B  (None, 28, 28, 256)          1024      ['conv2d_521[0][0]']
#  atchNormalization)
#
#  add_133 (Add)               (None, 28, 28, 256)          0         ['conv2d_522[0][0]',
#                                                                      'batch_normalization_445[0][0
#                                                                     ]']
#
#  activation_489 (Activation  (None, 28, 28, 256)          0         ['add_133[0][0]']
#  )
#
#  conv2d_523 (Conv2D)         (None, 28, 28, 64)           16448     ['activation_489[0][0]']
#
#  batch_normalization_446 (B  (None, 28, 28, 64)           256       ['conv2d_523[0][0]']
#  atchNormalization)
#
#  activation_490 (Activation  (None, 28, 28, 64)           0         ['batch_normalization_446[0][0
#  )                                                                  ]']
#
#  conv2d_524 (Conv2D)         (None, 28, 28, 64)           36928     ['activation_490[0][0]']
#
#  batch_normalization_447 (B  (None, 28, 28, 64)           256       ['conv2d_524[0][0]']
#  atchNormalization)
#
#  activation_491 (Activation  (None, 28, 28, 64)           0         ['batch_normalization_447[0][0
#  )                                                                  ]']
#
#  conv2d_525 (Conv2D)         (None, 28, 28, 256)          16640     ['activation_491[0][0]']
#
#  conv2d_526 (Conv2D)         (None, 28, 28, 256)          65792     ['activation_489[0][0]']
#
#  batch_normalization_448 (B  (None, 28, 28, 256)          1024      ['conv2d_525[0][0]']
#  atchNormalization)
#
#  add_134 (Add)               (None, 28, 28, 256)          0         ['conv2d_526[0][0]',
#                                                                      'batch_normalization_448[0][0
#                                                                     ]']
#
#  activation_492 (Activation  (None, 28, 28, 256)          0         ['add_134[0][0]']
#  )
#
#  conv2d_527 (Conv2D)         (None, 28, 28, 128)          32896     ['activation_492[0][0]']
#
#  batch_normalization_449 (B  (None, 28, 28, 128)          512       ['conv2d_527[0][0]']
#  atchNormalization)
#
#  activation_493 (Activation  (None, 28, 28, 128)          0         ['batch_normalization_449[0][0
#  )                                                                  ]']
#
#  conv2d_528 (Conv2D)         (None, 14, 14, 128)          147584    ['activation_493[0][0]']
#
#  batch_normalization_450 (B  (None, 14, 14, 128)          512       ['conv2d_528[0][0]']
#  atchNormalization)
#
#  activation_494 (Activation  (None, 14, 14, 128)          0         ['batch_normalization_450[0][0
#  )                                                                  ]']
#
#  conv2d_530 (Conv2D)         (None, 14, 14, 512)          131584    ['activation_492[0][0]']
#
#  conv2d_529 (Conv2D)         (None, 14, 14, 512)          66048     ['activation_494[0][0]']
#
#  batch_normalization_452 (B  (None, 14, 14, 512)          2048      ['conv2d_530[0][0]']
#  atchNormalization)
#
#  batch_normalization_451 (B  (None, 14, 14, 512)          2048      ['conv2d_529[0][0]']
#  atchNormalization)
#
#  add_135 (Add)               (None, 14, 14, 512)          0         ['batch_normalization_452[0][0
#                                                                     ]',
#                                                                      'batch_normalization_451[0][0
#                                                                     ]']
#
#  activation_495 (Activation  (None, 14, 14, 512)          0         ['add_135[0][0]']
#  )
#
#  conv2d_531 (Conv2D)         (None, 14, 14, 128)          65664     ['activation_495[0][0]']
#
#  batch_normalization_453 (B  (None, 14, 14, 128)          512       ['conv2d_531[0][0]']
#  atchNormalization)
#
#  activation_496 (Activation  (None, 14, 14, 128)          0         ['batch_normalization_453[0][0
#  )                                                                  ]']
#
#  conv2d_532 (Conv2D)         (None, 14, 14, 128)          147584    ['activation_496[0][0]']
#
#  batch_normalization_454 (B  (None, 14, 14, 128)          512       ['conv2d_532[0][0]']
#  atchNormalization)
#
#  activation_497 (Activation  (None, 14, 14, 128)          0         ['batch_normalization_454[0][0
#  )                                                                  ]']
#
#  conv2d_533 (Conv2D)         (None, 14, 14, 512)          66048     ['activation_497[0][0]']
#
#  conv2d_534 (Conv2D)         (None, 14, 14, 512)          262656    ['activation_495[0][0]']
#
#  batch_normalization_455 (B  (None, 14, 14, 512)          2048      ['conv2d_533[0][0]']
#  atchNormalization)
#
#  add_136 (Add)               (None, 14, 14, 512)          0         ['conv2d_534[0][0]',
#                                                                      'batch_normalization_455[0][0
#                                                                     ]']
#
#  activation_498 (Activation  (None, 14, 14, 512)          0         ['add_136[0][0]']
#  )
#
#  conv2d_535 (Conv2D)         (None, 14, 14, 128)          65664     ['activation_498[0][0]']
#
#  batch_normalization_456 (B  (None, 14, 14, 128)          512       ['conv2d_535[0][0]']
#  atchNormalization)
#
#  activation_499 (Activation  (None, 14, 14, 128)          0         ['batch_normalization_456[0][0
#  )                                                                  ]']
#
#  conv2d_536 (Conv2D)         (None, 14, 14, 128)          147584    ['activation_499[0][0]']
#
#  batch_normalization_457 (B  (None, 14, 14, 128)          512       ['conv2d_536[0][0]']
#  atchNormalization)
#
#  activation_500 (Activation  (None, 14, 14, 128)          0         ['batch_normalization_457[0][0
#  )                                                                  ]']
#
#  conv2d_537 (Conv2D)         (None, 14, 14, 512)          66048     ['activation_500[0][0]']
#
#  conv2d_538 (Conv2D)         (None, 14, 14, 512)          262656    ['activation_498[0][0]']
#
#  batch_normalization_458 (B  (None, 14, 14, 512)          2048      ['conv2d_537[0][0]']
#  atchNormalization)
#
#  add_137 (Add)               (None, 14, 14, 512)          0         ['conv2d_538[0][0]',
#                                                                      'batch_normalization_458[0][0
#                                                                     ]']
#
#  activation_501 (Activation  (None, 14, 14, 512)          0         ['add_137[0][0]']
#  )
#
#  conv2d_539 (Conv2D)         (None, 14, 14, 128)          65664     ['activation_501[0][0]']
#
#  batch_normalization_459 (B  (None, 14, 14, 128)          512       ['conv2d_539[0][0]']
#  atchNormalization)
#
#  activation_502 (Activation  (None, 14, 14, 128)          0         ['batch_normalization_459[0][0
#  )                                                                  ]']
#
#  conv2d_540 (Conv2D)         (None, 14, 14, 128)          147584    ['activation_502[0][0]']
#
#  batch_normalization_460 (B  (None, 14, 14, 128)          512       ['conv2d_540[0][0]']
#  atchNormalization)
#
#  activation_503 (Activation  (None, 14, 14, 128)          0         ['batch_normalization_460[0][0
#  )                                                                  ]']
#
#  conv2d_541 (Conv2D)         (None, 14, 14, 512)          66048     ['activation_503[0][0]']
#
#  conv2d_542 (Conv2D)         (None, 14, 14, 512)          262656    ['activation_501[0][0]']
#
#  batch_normalization_461 (B  (None, 14, 14, 512)          2048      ['conv2d_541[0][0]']
#  atchNormalization)
#
#  add_138 (Add)               (None, 14, 14, 512)          0         ['conv2d_542[0][0]',
#                                                                      'batch_normalization_461[0][0
#                                                                     ]']
#
#  activation_504 (Activation  (None, 14, 14, 512)          0         ['add_138[0][0]']
#  )
#
#  conv2d_543 (Conv2D)         (None, 14, 14, 256)          131328    ['activation_504[0][0]']
#
#  batch_normalization_462 (B  (None, 14, 14, 256)          1024      ['conv2d_543[0][0]']
#  atchNormalization)
#
#  activation_505 (Activation  (None, 14, 14, 256)          0         ['batch_normalization_462[0][0
#  )                                                                  ]']
#
#  conv2d_544 (Conv2D)         (None, 7, 7, 256)            590080    ['activation_505[0][0]']
#
#  batch_normalization_463 (B  (None, 7, 7, 256)            1024      ['conv2d_544[0][0]']
#  atchNormalization)
#
#  activation_506 (Activation  (None, 7, 7, 256)            0         ['batch_normalization_463[0][0
#  )                                                                  ]']
#
#  conv2d_546 (Conv2D)         (None, 7, 7, 1024)           525312    ['activation_504[0][0]']
#
#  conv2d_545 (Conv2D)         (None, 7, 7, 1024)           263168    ['activation_506[0][0]']
#
#  batch_normalization_465 (B  (None, 7, 7, 1024)           4096      ['conv2d_546[0][0]']
#  atchNormalization)
#
#  batch_normalization_464 (B  (None, 7, 7, 1024)           4096      ['conv2d_545[0][0]']
#  atchNormalization)
#
#  add_139 (Add)               (None, 7, 7, 1024)           0         ['batch_normalization_465[0][0
#                                                                     ]',
#                                                                      'batch_normalization_464[0][0
#                                                                     ]']
#
#  activation_507 (Activation  (None, 7, 7, 1024)           0         ['add_139[0][0]']
#  )
#
#  conv2d_547 (Conv2D)         (None, 7, 7, 256)            262400    ['activation_507[0][0]']
#
#  batch_normalization_466 (B  (None, 7, 7, 256)            1024      ['conv2d_547[0][0]']
#  atchNormalization)
#
#  activation_508 (Activation  (None, 7, 7, 256)            0         ['batch_normalization_466[0][0
#  )                                                                  ]']
#
#  conv2d_548 (Conv2D)         (None, 7, 7, 256)            590080    ['activation_508[0][0]']
#
#  batch_normalization_467 (B  (None, 7, 7, 256)            1024      ['conv2d_548[0][0]']
#  atchNormalization)
#
#  activation_509 (Activation  (None, 7, 7, 256)            0         ['batch_normalization_467[0][0
#  )                                                                  ]']
#
#  conv2d_549 (Conv2D)         (None, 7, 7, 1024)           263168    ['activation_509[0][0]']
#
#  conv2d_550 (Conv2D)         (None, 7, 7, 1024)           1049600   ['activation_507[0][0]']
#
#  batch_normalization_468 (B  (None, 7, 7, 1024)           4096      ['conv2d_549[0][0]']
#  atchNormalization)
#
#  add_140 (Add)               (None, 7, 7, 1024)           0         ['conv2d_550[0][0]',
#                                                                      'batch_normalization_468[0][0
#                                                                     ]']
#
#  activation_510 (Activation  (None, 7, 7, 1024)           0         ['add_140[0][0]']
#  )
#
#  conv2d_551 (Conv2D)         (None, 7, 7, 256)            262400    ['activation_510[0][0]']
#
#  batch_normalization_469 (B  (None, 7, 7, 256)            1024      ['conv2d_551[0][0]']
#  atchNormalization)
#
#  activation_511 (Activation  (None, 7, 7, 256)            0         ['batch_normalization_469[0][0
#  )                                                                  ]']
#
#  conv2d_552 (Conv2D)         (None, 7, 7, 256)            590080    ['activation_511[0][0]']
#
#  batch_normalization_470 (B  (None, 7, 7, 256)            1024      ['conv2d_552[0][0]']
#  atchNormalization)
#
#  activation_512 (Activation  (None, 7, 7, 256)            0         ['batch_normalization_470[0][0
#  )                                                                  ]']
#
#  conv2d_553 (Conv2D)         (None, 7, 7, 1024)           263168    ['activation_512[0][0]']
#
#  conv2d_554 (Conv2D)         (None, 7, 7, 1024)           1049600   ['activation_510[0][0]']
#
#  batch_normalization_471 (B  (None, 7, 7, 1024)           4096      ['conv2d_553[0][0]']
#  atchNormalization)
#
#  add_141 (Add)               (None, 7, 7, 1024)           0         ['conv2d_554[0][0]',
#                                                                      'batch_normalization_471[0][0
#                                                                     ]']
#
#  activation_513 (Activation  (None, 7, 7, 1024)           0         ['add_141[0][0]']
#  )
#
#  conv2d_555 (Conv2D)         (None, 7, 7, 256)            262400    ['activation_513[0][0]']
#
#  batch_normalization_472 (B  (None, 7, 7, 256)            1024      ['conv2d_555[0][0]']
#  atchNormalization)
#
#  activation_514 (Activation  (None, 7, 7, 256)            0         ['batch_normalization_472[0][0
#  )                                                                  ]']
#
#  conv2d_556 (Conv2D)         (None, 7, 7, 256)            590080    ['activation_514[0][0]']
#
#  batch_normalization_473 (B  (None, 7, 7, 256)            1024      ['conv2d_556[0][0]']
#  atchNormalization)
#
#  activation_515 (Activation  (None, 7, 7, 256)            0         ['batch_normalization_473[0][0
#  )                                                                  ]']
#
#  conv2d_557 (Conv2D)         (None, 7, 7, 1024)           263168    ['activation_515[0][0]']
#
#  conv2d_558 (Conv2D)         (None, 7, 7, 1024)           1049600   ['activation_513[0][0]']
#
#  batch_normalization_474 (B  (None, 7, 7, 1024)           4096      ['conv2d_557[0][0]']
#  atchNormalization)
#
#  add_142 (Add)               (None, 7, 7, 1024)           0         ['conv2d_558[0][0]',
#                                                                      'batch_normalization_474[0][0
#                                                                     ]']
#
#  activation_516 (Activation  (None, 7, 7, 1024)           0         ['add_142[0][0]']
#  )
#
#  conv2d_559 (Conv2D)         (None, 7, 7, 256)            262400    ['activation_516[0][0]']
#
#  batch_normalization_475 (B  (None, 7, 7, 256)            1024      ['conv2d_559[0][0]']
#  atchNormalization)
#
#  activation_517 (Activation  (None, 7, 7, 256)            0         ['batch_normalization_475[0][0
#  )                                                                  ]']
#
#  conv2d_560 (Conv2D)         (None, 7, 7, 256)            590080    ['activation_517[0][0]']
#
#  batch_normalization_476 (B  (None, 7, 7, 256)            1024      ['conv2d_560[0][0]']
#  atchNormalization)
#
#  activation_518 (Activation  (None, 7, 7, 256)            0         ['batch_normalization_476[0][0
#  )                                                                  ]']
#
#  conv2d_561 (Conv2D)         (None, 7, 7, 1024)           263168    ['activation_518[0][0]']
#
#  conv2d_562 (Conv2D)         (None, 7, 7, 1024)           1049600   ['activation_516[0][0]']
#
#  batch_normalization_477 (B  (None, 7, 7, 1024)           4096      ['conv2d_561[0][0]']
#  atchNormalization)
#
#  add_143 (Add)               (None, 7, 7, 1024)           0         ['conv2d_562[0][0]',
#                                                                      'batch_normalization_477[0][0
#                                                                     ]']
#
#  activation_519 (Activation  (None, 7, 7, 1024)           0         ['add_143[0][0]']
#  )
#
#  conv2d_563 (Conv2D)         (None, 7, 7, 256)            262400    ['activation_519[0][0]']
#
#  batch_normalization_478 (B  (None, 7, 7, 256)            1024      ['conv2d_563[0][0]']
#  atchNormalization)
#
#  activation_520 (Activation  (None, 7, 7, 256)            0         ['batch_normalization_478[0][0
#  )                                                                  ]']
#
#  conv2d_564 (Conv2D)         (None, 7, 7, 256)            590080    ['activation_520[0][0]']
#
#  batch_normalization_479 (B  (None, 7, 7, 256)            1024      ['conv2d_564[0][0]']
#  atchNormalization)
#
#  activation_521 (Activation  (None, 7, 7, 256)            0         ['batch_normalization_479[0][0
#  )                                                                  ]']
#
#  conv2d_565 (Conv2D)         (None, 7, 7, 1024)           263168    ['activation_521[0][0]']
#
#  conv2d_566 (Conv2D)         (None, 7, 7, 1024)           1049600   ['activation_519[0][0]']
#
#  batch_normalization_480 (B  (None, 7, 7, 1024)           4096      ['conv2d_565[0][0]']
#  atchNormalization)
#
#  add_144 (Add)               (None, 7, 7, 1024)           0         ['conv2d_566[0][0]',
#                                                                      'batch_normalization_480[0][0
#                                                                     ]']
#
#  activation_522 (Activation  (None, 7, 7, 1024)           0         ['add_144[0][0]']
#  )
#
#  conv2d_567 (Conv2D)         (None, 7, 7, 512)            524800    ['activation_522[0][0]']
#
#  batch_normalization_481 (B  (None, 7, 7, 512)            2048      ['conv2d_567[0][0]']
#  atchNormalization)
#
#  activation_523 (Activation  (None, 7, 7, 512)            0         ['batch_normalization_481[0][0
#  )                                                                  ]']
#
#  conv2d_568 (Conv2D)         (None, 4, 4, 512)            2359808   ['activation_523[0][0]']
#
#  batch_normalization_482 (B  (None, 4, 4, 512)            2048      ['conv2d_568[0][0]']
#  atchNormalization)
#
#  activation_524 (Activation  (None, 4, 4, 512)            0         ['batch_normalization_482[0][0
#  )                                                                  ]']
#
#  conv2d_570 (Conv2D)         (None, 4, 4, 2048)           2099200   ['activation_522[0][0]']
#
#  conv2d_569 (Conv2D)         (None, 4, 4, 2048)           1050624   ['activation_524[0][0]']
#
#  batch_normalization_484 (B  (None, 4, 4, 2048)           8192      ['conv2d_570[0][0]']
#  atchNormalization)
#
#  batch_normalization_483 (B  (None, 4, 4, 2048)           8192      ['conv2d_569[0][0]']
#  atchNormalization)
#
#  add_145 (Add)               (None, 4, 4, 2048)           0         ['batch_normalization_484[0][0
#                                                                     ]',
#                                                                      'batch_normalization_483[0][0
#                                                                     ]']
#
#  activation_525 (Activation  (None, 4, 4, 2048)           0         ['add_145[0][0]']
#  )
#
#  conv2d_571 (Conv2D)         (None, 4, 4, 512)            1049088   ['activation_525[0][0]']
#
#  batch_normalization_485 (B  (None, 4, 4, 512)            2048      ['conv2d_571[0][0]']
#  atchNormalization)
#
#  activation_526 (Activation  (None, 4, 4, 512)            0         ['batch_normalization_485[0][0
#  )                                                                  ]']
#
#  conv2d_572 (Conv2D)         (None, 4, 4, 512)            2359808   ['activation_526[0][0]']
#
#  batch_normalization_486 (B  (None, 4, 4, 512)            2048      ['conv2d_572[0][0]']
#  atchNormalization)
#
#  activation_527 (Activation  (None, 4, 4, 512)            0         ['batch_normalization_486[0][0
#  )                                                                  ]']
#
#  conv2d_573 (Conv2D)         (None, 4, 4, 2048)           1050624   ['activation_527[0][0]']
#
#  conv2d_574 (Conv2D)         (None, 4, 4, 2048)           4196352   ['activation_525[0][0]']
#
#  batch_normalization_487 (B  (None, 4, 4, 2048)           8192      ['conv2d_573[0][0]']
#  atchNormalization)
#
#  add_146 (Add)               (None, 4, 4, 2048)           0         ['conv2d_574[0][0]',
#                                                                      'batch_normalization_487[0][0
#                                                                     ]']
#
#  activation_528 (Activation  (None, 4, 4, 2048)           0         ['add_146[0][0]']
#  )
#
#  conv2d_575 (Conv2D)         (None, 4, 4, 512)            1049088   ['activation_528[0][0]']
#
#  batch_normalization_488 (B  (None, 4, 4, 512)            2048      ['conv2d_575[0][0]']
#  atchNormalization)
#
#  activation_529 (Activation  (None, 4, 4, 512)            0         ['batch_normalization_488[0][0
#  )                                                                  ]']
#
#  conv2d_576 (Conv2D)         (None, 4, 4, 512)            2359808   ['activation_529[0][0]']
#
#  batch_normalization_489 (B  (None, 4, 4, 512)            2048      ['conv2d_576[0][0]']
#  atchNormalization)
#
#  activation_530 (Activation  (None, 4, 4, 512)            0         ['batch_normalization_489[0][0
#  )                                                                  ]']
#
#  conv2d_577 (Conv2D)         (None, 4, 4, 2048)           1050624   ['activation_530[0][0]']
#
#  conv2d_578 (Conv2D)         (None, 4, 4, 2048)           4196352   ['activation_528[0][0]']
#
#  batch_normalization_490 (B  (None, 4, 4, 2048)           8192      ['conv2d_577[0][0]']
#  atchNormalization)
#
#  add_147 (Add)               (None, 4, 4, 2048)           0         ['conv2d_578[0][0]',
#                                                                      'batch_normalization_490[0][0
#                                                                     ]']
#
#  activation_531 (Activation  (None, 4, 4, 2048)           0         ['add_147[0][0]']
#  )
#
#  global_average_pooling2d_5  (None, 2048)                 0         ['activation_531[0][0]']
#   (GlobalAveragePooling2D)
#
#  flatten_5 (Flatten)         (None, 2048)                 0         ['global_average_pooling2d_5[0
#                                                                     ][0]']
#
#  dense_5 (Dense)             (None, 1000)                 2049000   ['flatten_5[0][0]']
#
# ==================================================================================================
# Total params: 40196968 (153.34 MB)
# Trainable params: 40143848 (153.14 MB)
# Non-trainable params: 53120 (207.50 KB)
# __________________________________________________________________________________________________

# %%
# ResNet101
model101 = ResNet(input_shape=(224, 224, 3), num_classes=1000, stages=[3,4,23,3], filters=[64,256,512,1024,2048])
model101.summary()
# Out:
# Model: "model_21"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_27 (InputLayer)       [(None, 224, 224, 3)]        0         []
#
#  conv2d_579 (Conv2D)         (None, 109, 109, 64)         9472      ['input_27[0][0]']
#
#  batch_normalization_491 (B  (None, 109, 109, 64)         256       ['conv2d_579[0][0]']
#  atchNormalization)
#
#  max_pooling2d_11 (MaxPooli  (None, 55, 55, 64)           0         ['batch_normalization_491[0][0
#  ng2D)                                                              ]']
#
#  conv2d_580 (Conv2D)         (None, 55, 55, 64)           4160      ['max_pooling2d_11[0][0]']
#
#  batch_normalization_492 (B  (None, 55, 55, 64)           256       ['conv2d_580[0][0]']
#  atchNormalization)
#
#  activation_532 (Activation  (None, 55, 55, 64)           0         ['batch_normalization_492[0][0
#  )                                                                  ]']
#
#  conv2d_581 (Conv2D)         (None, 28, 28, 64)           36928     ['activation_532[0][0]']
#
#  batch_normalization_493 (B  (None, 28, 28, 64)           256       ['conv2d_581[0][0]']
#  atchNormalization)
#
#  activation_533 (Activation  (None, 28, 28, 64)           0         ['batch_normalization_493[0][0
#  )                                                                  ]']
#
#  conv2d_583 (Conv2D)         (None, 28, 28, 256)          16640     ['max_pooling2d_11[0][0]']
#
#  conv2d_582 (Conv2D)         (None, 28, 28, 256)          16640     ['activation_533[0][0]']
#
#  batch_normalization_495 (B  (None, 28, 28, 256)          1024      ['conv2d_583[0][0]']
#  atchNormalization)
#
#  batch_normalization_494 (B  (None, 28, 28, 256)          1024      ['conv2d_582[0][0]']
#  atchNormalization)
#
#  add_148 (Add)               (None, 28, 28, 256)          0         ['batch_normalization_495[0][0
#                                                                     ]',
#                                                                      'batch_normalization_494[0][0
#                                                                     ]']
#
#  activation_534 (Activation  (None, 28, 28, 256)          0         ['add_148[0][0]']
#  )
#
#  conv2d_584 (Conv2D)         (None, 28, 28, 64)           16448     ['activation_534[0][0]']
#
#  batch_normalization_496 (B  (None, 28, 28, 64)           256       ['conv2d_584[0][0]']
#  atchNormalization)
#
#  activation_535 (Activation  (None, 28, 28, 64)           0         ['batch_normalization_496[0][0
#  )                                                                  ]']
#
#  conv2d_585 (Conv2D)         (None, 28, 28, 64)           36928     ['activation_535[0][0]']
#
#  batch_normalization_497 (B  (None, 28, 28, 64)           256       ['conv2d_585[0][0]']
#  atchNormalization)
#
#  activation_536 (Activation  (None, 28, 28, 64)           0         ['batch_normalization_497[0][0
#  )                                                                  ]']
#
#  conv2d_586 (Conv2D)         (None, 28, 28, 256)          16640     ['activation_536[0][0]']
#
#  conv2d_587 (Conv2D)         (None, 28, 28, 256)          65792     ['activation_534[0][0]']
#
#  batch_normalization_498 (B  (None, 28, 28, 256)          1024      ['conv2d_586[0][0]']
#  atchNormalization)
#
#  add_149 (Add)               (None, 28, 28, 256)          0         ['conv2d_587[0][0]',
#                                                                      'batch_normalization_498[0][0
#                                                                     ]']
#
#  activation_537 (Activation  (None, 28, 28, 256)          0         ['add_149[0][0]']
#  )
#
#  conv2d_588 (Conv2D)         (None, 28, 28, 64)           16448     ['activation_537[0][0]']
#
#  batch_normalization_499 (B  (None, 28, 28, 64)           256       ['conv2d_588[0][0]']
#  atchNormalization)
#
#  activation_538 (Activation  (None, 28, 28, 64)           0         ['batch_normalization_499[0][0
#  )                                                                  ]']
#
#  conv2d_589 (Conv2D)         (None, 28, 28, 64)           36928     ['activation_538[0][0]']
#
#  batch_normalization_500 (B  (None, 28, 28, 64)           256       ['conv2d_589[0][0]']
#  atchNormalization)
#
#  activation_539 (Activation  (None, 28, 28, 64)           0         ['batch_normalization_500[0][0
#  )                                                                  ]']
#
#  conv2d_590 (Conv2D)         (None, 28, 28, 256)          16640     ['activation_539[0][0]']
#
#  conv2d_591 (Conv2D)         (None, 28, 28, 256)          65792     ['activation_537[0][0]']
#
#  batch_normalization_501 (B  (None, 28, 28, 256)          1024      ['conv2d_590[0][0]']
#  atchNormalization)
#
#  add_150 (Add)               (None, 28, 28, 256)          0         ['conv2d_591[0][0]',
#                                                                      'batch_normalization_501[0][0
#                                                                     ]']
#
#  activation_540 (Activation  (None, 28, 28, 256)          0         ['add_150[0][0]']
#  )
#
#  conv2d_592 (Conv2D)         (None, 28, 28, 128)          32896     ['activation_540[0][0]']
#
#  batch_normalization_502 (B  (None, 28, 28, 128)          512       ['conv2d_592[0][0]']
#  atchNormalization)
#
#  activation_541 (Activation  (None, 28, 28, 128)          0         ['batch_normalization_502[0][0
#  )                                                                  ]']
#
#  conv2d_593 (Conv2D)         (None, 14, 14, 128)          147584    ['activation_541[0][0]']
#
#  batch_normalization_503 (B  (None, 14, 14, 128)          512       ['conv2d_593[0][0]']
#  atchNormalization)
#
#  activation_542 (Activation  (None, 14, 14, 128)          0         ['batch_normalization_503[0][0
#  )                                                                  ]']
#
#  conv2d_595 (Conv2D)         (None, 14, 14, 512)          131584    ['activation_540[0][0]']
#
#  conv2d_594 (Conv2D)         (None, 14, 14, 512)          66048     ['activation_542[0][0]']
#
#  batch_normalization_505 (B  (None, 14, 14, 512)          2048      ['conv2d_595[0][0]']
#  atchNormalization)
#
#  batch_normalization_504 (B  (None, 14, 14, 512)          2048      ['conv2d_594[0][0]']
#  atchNormalization)
#
#  add_151 (Add)               (None, 14, 14, 512)          0         ['batch_normalization_505[0][0
#                                                                     ]',
#                                                                      'batch_normalization_504[0][0
#                                                                     ]']
#
#  activation_543 (Activation  (None, 14, 14, 512)          0         ['add_151[0][0]']
#  )
#
#  conv2d_596 (Conv2D)         (None, 14, 14, 128)          65664     ['activation_543[0][0]']
#
#  batch_normalization_506 (B  (None, 14, 14, 128)          512       ['conv2d_596[0][0]']
#  atchNormalization)
#
#  activation_544 (Activation  (None, 14, 14, 128)          0         ['batch_normalization_506[0][0
#  )                                                                  ]']
#
#  conv2d_597 (Conv2D)         (None, 14, 14, 128)          147584    ['activation_544[0][0]']
#
#  batch_normalization_507 (B  (None, 14, 14, 128)          512       ['conv2d_597[0][0]']
#  atchNormalization)
#
#  activation_545 (Activation  (None, 14, 14, 128)          0         ['batch_normalization_507[0][0
#  )                                                                  ]']
#
#  conv2d_598 (Conv2D)         (None, 14, 14, 512)          66048     ['activation_545[0][0]']
#
#  conv2d_599 (Conv2D)         (None, 14, 14, 512)          262656    ['activation_543[0][0]']
#
#  batch_normalization_508 (B  (None, 14, 14, 512)          2048      ['conv2d_598[0][0]']
#  atchNormalization)
#
#  add_152 (Add)               (None, 14, 14, 512)          0         ['conv2d_599[0][0]',
#                                                                      'batch_normalization_508[0][0
#                                                                     ]']
#
#  activation_546 (Activation  (None, 14, 14, 512)          0         ['add_152[0][0]']
#  )
#
#  conv2d_600 (Conv2D)         (None, 14, 14, 128)          65664     ['activation_546[0][0]']
#
#  batch_normalization_509 (B  (None, 14, 14, 128)          512       ['conv2d_600[0][0]']
#  atchNormalization)
#
#  activation_547 (Activation  (None, 14, 14, 128)          0         ['batch_normalization_509[0][0
#  )                                                                  ]']
#
#  conv2d_601 (Conv2D)         (None, 14, 14, 128)          147584    ['activation_547[0][0]']
#
#  batch_normalization_510 (B  (None, 14, 14, 128)          512       ['conv2d_601[0][0]']
#  atchNormalization)
#
#  activation_548 (Activation  (None, 14, 14, 128)          0         ['batch_normalization_510[0][0
#  )                                                                  ]']
#
#  conv2d_602 (Conv2D)         (None, 14, 14, 512)          66048     ['activation_548[0][0]']
#
#  conv2d_603 (Conv2D)         (None, 14, 14, 512)          262656    ['activation_546[0][0]']
#
#  batch_normalization_511 (B  (None, 14, 14, 512)          2048      ['conv2d_602[0][0]']
#  atchNormalization)
#
#  add_153 (Add)               (None, 14, 14, 512)          0         ['conv2d_603[0][0]',
#                                                                      'batch_normalization_511[0][0
#                                                                     ]']
#
#  activation_549 (Activation  (None, 14, 14, 512)          0         ['add_153[0][0]']
#  )
#
#  conv2d_604 (Conv2D)         (None, 14, 14, 128)          65664     ['activation_549[0][0]']
#
#  batch_normalization_512 (B  (None, 14, 14, 128)          512       ['conv2d_604[0][0]']
#  atchNormalization)
#
#  activation_550 (Activation  (None, 14, 14, 128)          0         ['batch_normalization_512[0][0
#  )                                                                  ]']
#
#  conv2d_605 (Conv2D)         (None, 14, 14, 128)          147584    ['activation_550[0][0]']
#
#  batch_normalization_513 (B  (None, 14, 14, 128)          512       ['conv2d_605[0][0]']
#  atchNormalization)
#
#  activation_551 (Activation  (None, 14, 14, 128)          0         ['batch_normalization_513[0][0
#  )                                                                  ]']
#
#  conv2d_606 (Conv2D)         (None, 14, 14, 512)          66048     ['activation_551[0][0]']
#
#  conv2d_607 (Conv2D)         (None, 14, 14, 512)          262656    ['activation_549[0][0]']
#
#  batch_normalization_514 (B  (None, 14, 14, 512)          2048      ['conv2d_606[0][0]']
#  atchNormalization)
#
#  add_154 (Add)               (None, 14, 14, 512)          0         ['conv2d_607[0][0]',
#                                                                      'batch_normalization_514[0][0
#                                                                     ]']
#
#  activation_552 (Activation  (None, 14, 14, 512)          0         ['add_154[0][0]']
#  )
#
#  conv2d_608 (Conv2D)         (None, 14, 14, 256)          131328    ['activation_552[0][0]']
#
#  batch_normalization_515 (B  (None, 14, 14, 256)          1024      ['conv2d_608[0][0]']
#  atchNormalization)
#
#  activation_553 (Activation  (None, 14, 14, 256)          0         ['batch_normalization_515[0][0
#  )                                                                  ]']
#
#  conv2d_609 (Conv2D)         (None, 7, 7, 256)            590080    ['activation_553[0][0]']
#
#  batch_normalization_516 (B  (None, 7, 7, 256)            1024      ['conv2d_609[0][0]']
#  atchNormalization)
#
#  activation_554 (Activation  (None, 7, 7, 256)            0         ['batch_normalization_516[0][0
#  )                                                                  ]']
#
#  conv2d_611 (Conv2D)         (None, 7, 7, 1024)           525312    ['activation_552[0][0]']
#
#  conv2d_610 (Conv2D)         (None, 7, 7, 1024)           263168    ['activation_554[0][0]']
#
#  batch_normalization_518 (B  (None, 7, 7, 1024)           4096      ['conv2d_611[0][0]']
#  atchNormalization)
#
#  batch_normalization_517 (B  (None, 7, 7, 1024)           4096      ['conv2d_610[0][0]']
#  atchNormalization)
#
#  add_155 (Add)               (None, 7, 7, 1024)           0         ['batch_normalization_518[0][0
#                                                                     ]',
#                                                                      'batch_normalization_517[0][0
#                                                                     ]']
#
#  activation_555 (Activation  (None, 7, 7, 1024)           0         ['add_155[0][0]']
#  )
#
#  conv2d_612 (Conv2D)         (None, 7, 7, 256)            262400    ['activation_555[0][0]']
#
#  batch_normalization_519 (B  (None, 7, 7, 256)            1024      ['conv2d_612[0][0]']
#  atchNormalization)
#
#  activation_556 (Activation  (None, 7, 7, 256)            0         ['batch_normalization_519[0][0
#  )                                                                  ]']
#
#  conv2d_613 (Conv2D)         (None, 7, 7, 256)            590080    ['activation_556[0][0]']
#
#  batch_normalization_520 (B  (None, 7, 7, 256)            1024      ['conv2d_613[0][0]']
#  atchNormalization)
#
#  activation_557 (Activation  (None, 7, 7, 256)            0         ['batch_normalization_520[0][0
#  )                                                                  ]']
#
#  conv2d_614 (Conv2D)         (None, 7, 7, 1024)           263168    ['activation_557[0][0]']
#
#  conv2d_615 (Conv2D)         (None, 7, 7, 1024)           1049600   ['activation_555[0][0]']
#
#  batch_normalization_521 (B  (None, 7, 7, 1024)           4096      ['conv2d_614[0][0]']
#  atchNormalization)
#
#  add_156 (Add)               (None, 7, 7, 1024)           0         ['conv2d_615[0][0]',
#                                                                      'batch_normalization_521[0][0
#                                                                     ]']
#
#  activation_558 (Activation  (None, 7, 7, 1024)           0         ['add_156[0][0]']
#  )
#
#  conv2d_616 (Conv2D)         (None, 7, 7, 256)            262400    ['activation_558[0][0]']
#
#  batch_normalization_522 (B  (None, 7, 7, 256)            1024      ['conv2d_616[0][0]']
#  atchNormalization)
#
#  activation_559 (Activation  (None, 7, 7, 256)            0         ['batch_normalization_522[0][0
#  )                                                                  ]']
#
#  conv2d_617 (Conv2D)         (None, 7, 7, 256)            590080    ['activation_559[0][0]']
#
#  batch_normalization_523 (B  (None, 7, 7, 256)            1024      ['conv2d_617[0][0]']
#  atchNormalization)
#
#  activation_560 (Activation  (None, 7, 7, 256)            0         ['batch_normalization_523[0][0
#  )                                                                  ]']
#
#  conv2d_618 (Conv2D)         (None, 7, 7, 1024)           263168    ['activation_560[0][0]']
#
#  conv2d_619 (Conv2D)         (None, 7, 7, 1024)           1049600   ['activation_558[0][0]']
#
#  batch_normalization_524 (B  (None, 7, 7, 1024)           4096      ['conv2d_618[0][0]']
#  atchNormalization)
#
#  add_157 (Add)               (None, 7, 7, 1024)           0         ['conv2d_619[0][0]',
#                                                                      'batch_normalization_524[0][0
#                                                                     ]']
#
#  activation_561 (Activation  (None, 7, 7, 1024)           0         ['add_157[0][0]']
#  )
#
#  conv2d_620 (Conv2D)         (None, 7, 7, 256)            262400    ['activation_561[0][0]']
#
#  batch_normalization_525 (B  (None, 7, 7, 256)            1024      ['conv2d_620[0][0]']
#  atchNormalization)
#
#  activation_562 (Activation  (None, 7, 7, 256)            0         ['batch_normalization_525[0][0
#  )                                                                  ]']
#
#  conv2d_621 (Conv2D)         (None, 7, 7, 256)            590080    ['activation_562[0][0]']
#
#  batch_normalization_526 (B  (None, 7, 7, 256)            1024      ['conv2d_621[0][0]']
#  atchNormalization)
#
#  activation_563 (Activation  (None, 7, 7, 256)            0         ['batch_normalization_526[0][0
#  )                                                                  ]']
#
#  conv2d_622 (Conv2D)         (None, 7, 7, 1024)           263168    ['activation_563[0][0]']
#
#  conv2d_623 (Conv2D)         (None, 7, 7, 1024)           1049600   ['activation_561[0][0]']
#
#  batch_normalization_527 (B  (None, 7, 7, 1024)           4096      ['conv2d_622[0][0]']
#  atchNormalization)
#
#  add_158 (Add)               (None, 7, 7, 1024)           0         ['conv2d_623[0][0]',
#                                                                      'batch_normalization_527[0][0
#                                                                     ]']
#
#  activation_564 (Activation  (None, 7, 7, 1024)           0         ['add_158[0][0]']
#  )
#
#  conv2d_624 (Conv2D)         (None, 7, 7, 256)            262400    ['activation_564[0][0]']
#
#  batch_normalization_528 (B  (None, 7, 7, 256)            1024      ['conv2d_624[0][0]']
#  atchNormalization)
#
#  activation_565 (Activation  (None, 7, 7, 256)            0         ['batch_normalization_528[0][0
#  )                                                                  ]']
#
#  conv2d_625 (Conv2D)         (None, 7, 7, 256)            590080    ['activation_565[0][0]']
#
#  batch_normalization_529 (B  (None, 7, 7, 256)            1024      ['conv2d_625[0][0]']
#  atchNormalization)
#
#  activation_566 (Activation  (None, 7, 7, 256)            0         ['batch_normalization_529[0][0
#  )                                                                  ]']
#
#  conv2d_626 (Conv2D)         (None, 7, 7, 1024)           263168    ['activation_566[0][0]']
#
#  conv2d_627 (Conv2D)         (None, 7, 7, 1024)           1049600   ['activation_564[0][0]']
#
#  batch_normalization_530 (B  (None, 7, 7, 1024)           4096      ['conv2d_626[0][0]']
#  atchNormalization)
#
#  add_159 (Add)               (None, 7, 7, 1024)           0         ['conv2d_627[0][0]',
#                                                                      'batch_normalization_530[0][0
#                                                                     ]']
#
#  activation_567 (Activation  (None, 7, 7, 1024)           0         ['add_159[0][0]']
#  )
#
#  conv2d_628 (Conv2D)         (None, 7, 7, 256)            262400    ['activation_567[0][0]']
#
#  batch_normalization_531 (B  (None, 7, 7, 256)            1024      ['conv2d_628[0][0]']
#  atchNormalization)
#
#  activation_568 (Activation  (None, 7, 7, 256)            0         ['batch_normalization_531[0][0
#  )                                                                  ]']
#
#  conv2d_629 (Conv2D)         (None, 7, 7, 256)            590080    ['activation_568[0][0]']
#
#  batch_normalization_532 (B  (None, 7, 7, 256)            1024      ['conv2d_629[0][0]']
#  atchNormalization)
#
#  activation_569 (Activation  (None, 7, 7, 256)            0         ['batch_normalization_532[0][0
#  )                                                                  ]']
#
#  conv2d_630 (Conv2D)         (None, 7, 7, 1024)           263168    ['activation_569[0][0]']
#
#  conv2d_631 (Conv2D)         (None, 7, 7, 1024)           1049600   ['activation_567[0][0]']
#
#  batch_normalization_533 (B  (None, 7, 7, 1024)           4096      ['conv2d_630[0][0]']
#  atchNormalization)
#
#  add_160 (Add)               (None, 7, 7, 1024)           0         ['conv2d_631[0][0]',
#                                                                      'batch_normalization_533[0][0
#                                                                     ]']
#
#  activation_570 (Activation  (None, 7, 7, 1024)           0         ['add_160[0][0]']
#  )
#
#  conv2d_632 (Conv2D)         (None, 7, 7, 256)            262400    ['activation_570[0][0]']
#
#  batch_normalization_534 (B  (None, 7, 7, 256)            1024      ['conv2d_632[0][0]']
#  atchNormalization)
#
#  activation_571 (Activation  (None, 7, 7, 256)            0         ['batch_normalization_534[0][0
#  )                                                                  ]']
#
#  conv2d_633 (Conv2D)         (None, 7, 7, 256)            590080    ['activation_571[0][0]']
#
#  batch_normalization_535 (B  (None, 7, 7, 256)            1024      ['conv2d_633[0][0]']
#  atchNormalization)
#
#  activation_572 (Activation  (None, 7, 7, 256)            0         ['batch_normalization_535[0][0
#  )                                                                  ]']
#
#  conv2d_634 (Conv2D)         (None, 7, 7, 1024)           263168    ['activation_572[0][0]']
#
#  conv2d_635 (Conv2D)         (None, 7, 7, 1024)           1049600   ['activation_570[0][0]']
#
#  batch_normalization_536 (B  (None, 7, 7, 1024)           4096      ['conv2d_634[0][0]']
#  atchNormalization)
#
#  add_161 (Add)               (None, 7, 7, 1024)           0         ['conv2d_635[0][0]',
#                                                                      'batch_normalization_536[0][0
#                                                                     ]']
#
#  activation_573 (Activation  (None, 7, 7, 1024)           0         ['add_161[0][0]']
#  )
#
#  conv2d_636 (Conv2D)         (None, 7, 7, 256)            262400    ['activation_573[0][0]']
#
#  batch_normalization_537 (B  (None, 7, 7, 256)            1024      ['conv2d_636[0][0]']
#  atchNormalization)
#
#  activation_574 (Activation  (None, 7, 7, 256)            0         ['batch_normalization_537[0][0
#  )                                                                  ]']
#
#  conv2d_637 (Conv2D)         (None, 7, 7, 256)            590080    ['activation_574[0][0]']
#
#  batch_normalization_538 (B  (None, 7, 7, 256)            1024      ['conv2d_637[0][0]']
#  atchNormalization)
#
#  activation_575 (Activation  (None, 7, 7, 256)            0         ['batch_normalization_538[0][0
#  )                                                                  ]']
#
#  conv2d_638 (Conv2D)         (None, 7, 7, 1024)           263168    ['activation_575[0][0]']
#
#  conv2d_639 (Conv2D)         (None, 7, 7, 1024)           1049600   ['activation_573[0][0]']
#
#  batch_normalization_539 (B  (None, 7, 7, 1024)           4096      ['conv2d_638[0][0]']
#  atchNormalization)
#
#  add_162 (Add)               (None, 7, 7, 1024)           0         ['conv2d_639[0][0]',
#                                                                      'batch_normalization_539[0][0
#                                                                     ]']
#
#  activation_576 (Activation  (None, 7, 7, 1024)           0         ['add_162[0][0]']
#  )
#
#  conv2d_640 (Conv2D)         (None, 7, 7, 256)            262400    ['activation_576[0][0]']
#
#  batch_normalization_540 (B  (None, 7, 7, 256)            1024      ['conv2d_640[0][0]']
#  atchNormalization)
#
#  activation_577 (Activation  (None, 7, 7, 256)            0         ['batch_normalization_540[0][0
#  )                                                                  ]']
#
#  conv2d_641 (Conv2D)         (None, 7, 7, 256)            590080    ['activation_577[0][0]']
# ...
#
#  activation_616 (Activation  (None, 7, 7, 256)            0         ['batch_normalization_579[0][0
#  )                                                                  ]']
#
#  conv2d_693 (Conv2D)         (None, 7, 7, 256)            590080    ['activation_616[0][0]']
#
#  batch_normalization_580 (B  (None, 7, 7, 256)            1024      ['conv2d_693[0][0]']
#  atchNormalization)
#
#  activation_617 (Activation  (None, 7, 7, 256)            0         ['batch_normalization_580[0][0
#  )                                                                  ]']
#
#  conv2d_694 (Conv2D)         (None, 7, 7, 1024)           263168    ['activation_617[0][0]']
#
#  conv2d_695 (Conv2D)         (None, 7, 7, 1024)           1049600   ['activation_615[0][0]']
#
#  batch_normalization_581 (B  (None, 7, 7, 1024)           4096      ['conv2d_694[0][0]']
#  atchNormalization)
#
#  add_176 (Add)               (None, 7, 7, 1024)           0         ['conv2d_695[0][0]',
#                                                                      'batch_normalization_581[0][0
#                                                                     ]']
#
#  activation_618 (Activation  (None, 7, 7, 1024)           0         ['add_176[0][0]']
#  )
#
#  conv2d_696 (Conv2D)         (None, 7, 7, 256)            262400    ['activation_618[0][0]']
#
#  batch_normalization_582 (B  (None, 7, 7, 256)            1024      ['conv2d_696[0][0]']
#  atchNormalization)
#
#  activation_619 (Activation  (None, 7, 7, 256)            0         ['batch_normalization_582[0][0
#  )                                                                  ]']
#
#  conv2d_697 (Conv2D)         (None, 7, 7, 256)            590080    ['activation_619[0][0]']
#
#  batch_normalization_583 (B  (None, 7, 7, 256)            1024      ['conv2d_697[0][0]']
#  atchNormalization)
#
#  activation_620 (Activation  (None, 7, 7, 256)            0         ['batch_normalization_583[0][0
#  )                                                                  ]']
#
#  conv2d_698 (Conv2D)         (None, 7, 7, 1024)           263168    ['activation_620[0][0]']
#
#  conv2d_699 (Conv2D)         (None, 7, 7, 1024)           1049600   ['activation_618[0][0]']
#
#  batch_normalization_584 (B  (None, 7, 7, 1024)           4096      ['conv2d_698[0][0]']
#  atchNormalization)
#
#  add_177 (Add)               (None, 7, 7, 1024)           0         ['conv2d_699[0][0]',
#                                                                      'batch_normalization_584[0][0
#                                                                     ]']
#
#  activation_621 (Activation  (None, 7, 7, 1024)           0         ['add_177[0][0]']
#  )
#
#  conv2d_700 (Conv2D)         (None, 7, 7, 512)            524800    ['activation_621[0][0]']
#
#  batch_normalization_585 (B  (None, 7, 7, 512)            2048      ['conv2d_700[0][0]']
#  atchNormalization)
#
#  activation_622 (Activation  (None, 7, 7, 512)            0         ['batch_normalization_585[0][0
#  )                                                                  ]']
#
#  conv2d_701 (Conv2D)         (None, 4, 4, 512)            2359808   ['activation_622[0][0]']
#
#  batch_normalization_586 (B  (None, 4, 4, 512)            2048      ['conv2d_701[0][0]']
#  atchNormalization)
#
#  activation_623 (Activation  (None, 4, 4, 512)            0         ['batch_normalization_586[0][0
#  )                                                                  ]']
#
#  conv2d_703 (Conv2D)         (None, 4, 4, 2048)           2099200   ['activation_621[0][0]']
#
#  conv2d_702 (Conv2D)         (None, 4, 4, 2048)           1050624   ['activation_623[0][0]']
#
#  batch_normalization_588 (B  (None, 4, 4, 2048)           8192      ['conv2d_703[0][0]']
#  atchNormalization)
#
#  batch_normalization_587 (B  (None, 4, 4, 2048)           8192      ['conv2d_702[0][0]']
#  atchNormalization)
#
#  add_178 (Add)               (None, 4, 4, 2048)           0         ['batch_normalization_588[0][0
#                                                                     ]',
#                                                                      'batch_normalization_587[0][0
#                                                                     ]']
#
#  activation_624 (Activation  (None, 4, 4, 2048)           0         ['add_178[0][0]']
#  )
#
#  conv2d_704 (Conv2D)         (None, 4, 4, 512)            1049088   ['activation_624[0][0]']
#
#  batch_normalization_589 (B  (None, 4, 4, 512)            2048      ['conv2d_704[0][0]']
#  atchNormalization)
#
#  activation_625 (Activation  (None, 4, 4, 512)            0         ['batch_normalization_589[0][0
#  )                                                                  ]']
#
#  conv2d_705 (Conv2D)         (None, 4, 4, 512)            2359808   ['activation_625[0][0]']
#
#  batch_normalization_590 (B  (None, 4, 4, 512)            2048      ['conv2d_705[0][0]']
#  atchNormalization)
#
#  activation_626 (Activation  (None, 4, 4, 512)            0         ['batch_normalization_590[0][0
#  )                                                                  ]']
#
#  conv2d_706 (Conv2D)         (None, 4, 4, 2048)           1050624   ['activation_626[0][0]']
#
#  conv2d_707 (Conv2D)         (None, 4, 4, 2048)           4196352   ['activation_624[0][0]']
#
#  batch_normalization_591 (B  (None, 4, 4, 2048)           8192      ['conv2d_706[0][0]']
#  atchNormalization)
#
#  add_179 (Add)               (None, 4, 4, 2048)           0         ['conv2d_707[0][0]',
#                                                                      'batch_normalization_591[0][0
#                                                                     ]']
#
#  activation_627 (Activation  (None, 4, 4, 2048)           0         ['add_179[0][0]']
#  )
#
#  conv2d_708 (Conv2D)         (None, 4, 4, 512)            1049088   ['activation_627[0][0]']
#
#  batch_normalization_592 (B  (None, 4, 4, 512)            2048      ['conv2d_708[0][0]']
#  atchNormalization)
#
#  activation_628 (Activation  (None, 4, 4, 512)            0         ['batch_normalization_592[0][0
#  )                                                                  ]']
#
#  conv2d_709 (Conv2D)         (None, 4, 4, 512)            2359808   ['activation_628[0][0]']
#
#  batch_normalization_593 (B  (None, 4, 4, 512)            2048      ['conv2d_709[0][0]']
#  atchNormalization)
#
#  activation_629 (Activation  (None, 4, 4, 512)            0         ['batch_normalization_593[0][0
#  )                                                                  ]']
#
#  conv2d_710 (Conv2D)         (None, 4, 4, 2048)           1050624   ['activation_629[0][0]']
#
#  conv2d_711 (Conv2D)         (None, 4, 4, 2048)           4196352   ['activation_627[0][0]']
#
#  batch_normalization_594 (B  (None, 4, 4, 2048)           8192      ['conv2d_710[0][0]']
#  atchNormalization)
#
#  add_180 (Add)               (None, 4, 4, 2048)           0         ['conv2d_711[0][0]',
#                                                                      'batch_normalization_594[0][0
#                                                                     ]']
#
#  activation_630 (Activation  (None, 4, 4, 2048)           0         ['add_180[0][0]']
#  )
#
#  global_average_pooling2d_6  (None, 2048)                 0         ['activation_630[0][0]']
#   (GlobalAveragePooling2D)
#
#  flatten_6 (Flatten)         (None, 2048)                 0         ['global_average_pooling2d_6[0
#                                                                     ][0]']
#
#  dense_6 (Dense)             (None, 1000)                 2049000   ['flatten_6[0][0]']
#
# ==================================================================================================
# Total params: 77110632 (294.15 MB)
# Trainable params: 77005288 (293.75 MB)
# Non-trainable params: 105344 (411.50 KB)
# __________________________________________________________________________________________________

# %%
# ResNet152
model152 = ResNet(input_shape=(224, 224, 3), num_classes=1000, stages=[3,8,36,3], filters=[64,256,512,1024,2048])
model152.summary()
# Out:
# Model: "model_22"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_28 (InputLayer)       [(None, 224, 224, 3)]        0         []
#
#  conv2d_712 (Conv2D)         (None, 109, 109, 64)         9472      ['input_28[0][0]']
#
#  batch_normalization_595 (B  (None, 109, 109, 64)         256       ['conv2d_712[0][0]']
#  atchNormalization)
#
#  max_pooling2d_12 (MaxPooli  (None, 55, 55, 64)           0         ['batch_normalization_595[0][0
#  ng2D)                                                              ]']
#
#  conv2d_713 (Conv2D)         (None, 55, 55, 64)           4160      ['max_pooling2d_12[0][0]']
#
#  batch_normalization_596 (B  (None, 55, 55, 64)           256       ['conv2d_713[0][0]']
#  atchNormalization)
#
#  activation_631 (Activation  (None, 55, 55, 64)           0         ['batch_normalization_596[0][0
#  )                                                                  ]']
#
#  conv2d_714 (Conv2D)         (None, 28, 28, 64)           36928     ['activation_631[0][0]']
#
#  batch_normalization_597 (B  (None, 28, 28, 64)           256       ['conv2d_714[0][0]']
#  atchNormalization)
#
#  activation_632 (Activation  (None, 28, 28, 64)           0         ['batch_normalization_597[0][0
#  )                                                                  ]']
#
#  conv2d_716 (Conv2D)         (None, 28, 28, 256)          16640     ['max_pooling2d_12[0][0]']
#
#  conv2d_715 (Conv2D)         (None, 28, 28, 256)          16640     ['activation_632[0][0]']
#
#  batch_normalization_599 (B  (None, 28, 28, 256)          1024      ['conv2d_716[0][0]']
#  atchNormalization)
#
#  batch_normalization_598 (B  (None, 28, 28, 256)          1024      ['conv2d_715[0][0]']
#  atchNormalization)
#
#  add_181 (Add)               (None, 28, 28, 256)          0         ['batch_normalization_599[0][0
#                                                                     ]',
#                                                                      'batch_normalization_598[0][0
#                                                                     ]']
#
#  activation_633 (Activation  (None, 28, 28, 256)          0         ['add_181[0][0]']
#  )
#
#  conv2d_717 (Conv2D)         (None, 28, 28, 64)           16448     ['activation_633[0][0]']
#
#  batch_normalization_600 (B  (None, 28, 28, 64)           256       ['conv2d_717[0][0]']
#  atchNormalization)
#
#  activation_634 (Activation  (None, 28, 28, 64)           0         ['batch_normalization_600[0][0
#  )                                                                  ]']
#
#  conv2d_718 (Conv2D)         (None, 28, 28, 64)           36928     ['activation_634[0][0]']
#
#  batch_normalization_601 (B  (None, 28, 28, 64)           256       ['conv2d_718[0][0]']
#  atchNormalization)
#
#  activation_635 (Activation  (None, 28, 28, 64)           0         ['batch_normalization_601[0][0
#  )                                                                  ]']
#
#  conv2d_719 (Conv2D)         (None, 28, 28, 256)          16640     ['activation_635[0][0]']
#
#  conv2d_720 (Conv2D)         (None, 28, 28, 256)          65792     ['activation_633[0][0]']
#
#  batch_normalization_602 (B  (None, 28, 28, 256)          1024      ['conv2d_719[0][0]']
#  atchNormalization)
#
#  add_182 (Add)               (None, 28, 28, 256)          0         ['conv2d_720[0][0]',
#                                                                      'batch_normalization_602[0][0
#                                                                     ]']
#
#  activation_636 (Activation  (None, 28, 28, 256)          0         ['add_182[0][0]']
#  )
#
#  conv2d_721 (Conv2D)         (None, 28, 28, 64)           16448     ['activation_636[0][0]']
#
#  batch_normalization_603 (B  (None, 28, 28, 64)           256       ['conv2d_721[0][0]']
#  atchNormalization)
#
#  activation_637 (Activation  (None, 28, 28, 64)           0         ['batch_normalization_603[0][0
#  )                                                                  ]']
#
#  conv2d_722 (Conv2D)         (None, 28, 28, 64)           36928     ['activation_637[0][0]']
#
#  batch_normalization_604 (B  (None, 28, 28, 64)           256       ['conv2d_722[0][0]']
#  atchNormalization)
#
#  activation_638 (Activation  (None, 28, 28, 64)           0         ['batch_normalization_604[0][0
#  )                                                                  ]']
#
#  conv2d_723 (Conv2D)         (None, 28, 28, 256)          16640     ['activation_638[0][0]']
#
#  conv2d_724 (Conv2D)         (None, 28, 28, 256)          65792     ['activation_636[0][0]']
#
#  batch_normalization_605 (B  (None, 28, 28, 256)          1024      ['conv2d_723[0][0]']
#  atchNormalization)
#
#  add_183 (Add)               (None, 28, 28, 256)          0         ['conv2d_724[0][0]',
#                                                                      'batch_normalization_605[0][0
#                                                                     ]']
#
#  activation_639 (Activation  (None, 28, 28, 256)          0         ['add_183[0][0]']
#  )
#
#  conv2d_725 (Conv2D)         (None, 28, 28, 128)          32896     ['activation_639[0][0]']
#
#  batch_normalization_606 (B  (None, 28, 28, 128)          512       ['conv2d_725[0][0]']
#  atchNormalization)
#
#  activation_640 (Activation  (None, 28, 28, 128)          0         ['batch_normalization_606[0][0
#  )                                                                  ]']
#
#  conv2d_726 (Conv2D)         (None, 14, 14, 128)          147584    ['activation_640[0][0]']
#
#  batch_normalization_607 (B  (None, 14, 14, 128)          512       ['conv2d_726[0][0]']
#  atchNormalization)
#
#  activation_641 (Activation  (None, 14, 14, 128)          0         ['batch_normalization_607[0][0
#  )                                                                  ]']
#
#  conv2d_728 (Conv2D)         (None, 14, 14, 512)          131584    ['activation_639[0][0]']
#
#  conv2d_727 (Conv2D)         (None, 14, 14, 512)          66048     ['activation_641[0][0]']
#
#  batch_normalization_609 (B  (None, 14, 14, 512)          2048      ['conv2d_728[0][0]']
#  atchNormalization)
#
#  batch_normalization_608 (B  (None, 14, 14, 512)          2048      ['conv2d_727[0][0]']
#  atchNormalization)
#
#  add_184 (Add)               (None, 14, 14, 512)          0         ['batch_normalization_609[0][0
#                                                                     ]',
#                                                                      'batch_normalization_608[0][0
#                                                                     ]']
#
#  activation_642 (Activation  (None, 14, 14, 512)          0         ['add_184[0][0]']
#  )
#
#  conv2d_729 (Conv2D)         (None, 14, 14, 128)          65664     ['activation_642[0][0]']
#
#  batch_normalization_610 (B  (None, 14, 14, 128)          512       ['conv2d_729[0][0]']
#  atchNormalization)
#
#  activation_643 (Activation  (None, 14, 14, 128)          0         ['batch_normalization_610[0][0
#  )                                                                  ]']
#
#  conv2d_730 (Conv2D)         (None, 14, 14, 128)          147584    ['activation_643[0][0]']
#
#  batch_normalization_611 (B  (None, 14, 14, 128)          512       ['conv2d_730[0][0]']
#  atchNormalization)
#
#  activation_644 (Activation  (None, 14, 14, 128)          0         ['batch_normalization_611[0][0
#  )                                                                  ]']
#
#  conv2d_731 (Conv2D)         (None, 14, 14, 512)          66048     ['activation_644[0][0]']
#
#  conv2d_732 (Conv2D)         (None, 14, 14, 512)          262656    ['activation_642[0][0]']
#
#  batch_normalization_612 (B  (None, 14, 14, 512)          2048      ['conv2d_731[0][0]']
#  atchNormalization)
#
#  add_185 (Add)               (None, 14, 14, 512)          0         ['conv2d_732[0][0]',
#                                                                      'batch_normalization_612[0][0
#                                                                     ]']
#
#  activation_645 (Activation  (None, 14, 14, 512)          0         ['add_185[0][0]']
#  )
#
#  conv2d_733 (Conv2D)         (None, 14, 14, 128)          65664     ['activation_645[0][0]']
#
#  batch_normalization_613 (B  (None, 14, 14, 128)          512       ['conv2d_733[0][0]']
#  atchNormalization)
#
#  activation_646 (Activation  (None, 14, 14, 128)          0         ['batch_normalization_613[0][0
#  )                                                                  ]']
#
#  conv2d_734 (Conv2D)         (None, 14, 14, 128)          147584    ['activation_646[0][0]']
#
#  batch_normalization_614 (B  (None, 14, 14, 128)          512       ['conv2d_734[0][0]']
#  atchNormalization)
#
#  activation_647 (Activation  (None, 14, 14, 128)          0         ['batch_normalization_614[0][0
#  )                                                                  ]']
#
#  conv2d_735 (Conv2D)         (None, 14, 14, 512)          66048     ['activation_647[0][0]']
#
#  conv2d_736 (Conv2D)         (None, 14, 14, 512)          262656    ['activation_645[0][0]']
#
#  batch_normalization_615 (B  (None, 14, 14, 512)          2048      ['conv2d_735[0][0]']
#  atchNormalization)
#
#  add_186 (Add)               (None, 14, 14, 512)          0         ['conv2d_736[0][0]',
#                                                                      'batch_normalization_615[0][0
#                                                                     ]']
#
#  activation_648 (Activation  (None, 14, 14, 512)          0         ['add_186[0][0]']
#  )
#
#  conv2d_737 (Conv2D)         (None, 14, 14, 128)          65664     ['activation_648[0][0]']
#
#  batch_normalization_616 (B  (None, 14, 14, 128)          512       ['conv2d_737[0][0]']
#  atchNormalization)
#
#  activation_649 (Activation  (None, 14, 14, 128)          0         ['batch_normalization_616[0][0
#  )                                                                  ]']
#
#  conv2d_738 (Conv2D)         (None, 14, 14, 128)          147584    ['activation_649[0][0]']
#
#  batch_normalization_617 (B  (None, 14, 14, 128)          512       ['conv2d_738[0][0]']
#  atchNormalization)
#
#  activation_650 (Activation  (None, 14, 14, 128)          0         ['batch_normalization_617[0][0
#  )                                                                  ]']
#
#  conv2d_739 (Conv2D)         (None, 14, 14, 512)          66048     ['activation_650[0][0]']
#
#  conv2d_740 (Conv2D)         (None, 14, 14, 512)          262656    ['activation_648[0][0]']
#
#  batch_normalization_618 (B  (None, 14, 14, 512)          2048      ['conv2d_739[0][0]']
#  atchNormalization)
#
#  add_187 (Add)               (None, 14, 14, 512)          0         ['conv2d_740[0][0]',
#                                                                      'batch_normalization_618[0][0
#                                                                     ]']
#
#  activation_651 (Activation  (None, 14, 14, 512)          0         ['add_187[0][0]']
#  )
#
#  conv2d_741 (Conv2D)         (None, 14, 14, 128)          65664     ['activation_651[0][0]']
#
#  batch_normalization_619 (B  (None, 14, 14, 128)          512       ['conv2d_741[0][0]']
#  atchNormalization)
#
#  activation_652 (Activation  (None, 14, 14, 128)          0         ['batch_normalization_619[0][0
#  )                                                                  ]']
#
#  conv2d_742 (Conv2D)         (None, 14, 14, 128)          147584    ['activation_652[0][0]']
#
#  batch_normalization_620 (B  (None, 14, 14, 128)          512       ['conv2d_742[0][0]']
#  atchNormalization)
#
#  activation_653 (Activation  (None, 14, 14, 128)          0         ['batch_normalization_620[0][0
#  )                                                                  ]']
#
#  conv2d_743 (Conv2D)         (None, 14, 14, 512)          66048     ['activation_653[0][0]']
#
#  conv2d_744 (Conv2D)         (None, 14, 14, 512)          262656    ['activation_651[0][0]']
#
#  batch_normalization_621 (B  (None, 14, 14, 512)          2048      ['conv2d_743[0][0]']
#  atchNormalization)
#
#  add_188 (Add)               (None, 14, 14, 512)          0         ['conv2d_744[0][0]',
#                                                                      'batch_normalization_621[0][0
#                                                                     ]']
#
#  activation_654 (Activation  (None, 14, 14, 512)          0         ['add_188[0][0]']
#  )
#
#  conv2d_745 (Conv2D)         (None, 14, 14, 128)          65664     ['activation_654[0][0]']
#
#  batch_normalization_622 (B  (None, 14, 14, 128)          512       ['conv2d_745[0][0]']
#  atchNormalization)
#
#  activation_655 (Activation  (None, 14, 14, 128)          0         ['batch_normalization_622[0][0
#  )                                                                  ]']
#
#  conv2d_746 (Conv2D)         (None, 14, 14, 128)          147584    ['activation_655[0][0]']
#
#  batch_normalization_623 (B  (None, 14, 14, 128)          512       ['conv2d_746[0][0]']
#  atchNormalization)
#
#  activation_656 (Activation  (None, 14, 14, 128)          0         ['batch_normalization_623[0][0
#  )                                                                  ]']
#
#  conv2d_747 (Conv2D)         (None, 14, 14, 512)          66048     ['activation_656[0][0]']
#
#  conv2d_748 (Conv2D)         (None, 14, 14, 512)          262656    ['activation_654[0][0]']
#
#  batch_normalization_624 (B  (None, 14, 14, 512)          2048      ['conv2d_747[0][0]']
#  atchNormalization)
#
#  add_189 (Add)               (None, 14, 14, 512)          0         ['conv2d_748[0][0]',
#                                                                      'batch_normalization_624[0][0
#                                                                     ]']
#
#  activation_657 (Activation  (None, 14, 14, 512)          0         ['add_189[0][0]']
#  )
#
#  conv2d_749 (Conv2D)         (None, 14, 14, 128)          65664     ['activation_657[0][0]']
#
#  batch_normalization_625 (B  (None, 14, 14, 128)          512       ['conv2d_749[0][0]']
#  atchNormalization)
#
#  activation_658 (Activation  (None, 14, 14, 128)          0         ['batch_normalization_625[0][0
#  )                                                                  ]']
#
#  conv2d_750 (Conv2D)         (None, 14, 14, 128)          147584    ['activation_658[0][0]']
#
#  batch_normalization_626 (B  (None, 14, 14, 128)          512       ['conv2d_750[0][0]']
#  atchNormalization)
#
#  activation_659 (Activation  (None, 14, 14, 128)          0         ['batch_normalization_626[0][0
#  )                                                                  ]']
#
#  conv2d_751 (Conv2D)         (None, 14, 14, 512)          66048     ['activation_659[0][0]']
#
#  conv2d_752 (Conv2D)         (None, 14, 14, 512)          262656    ['activation_657[0][0]']
#
#  batch_normalization_627 (B  (None, 14, 14, 512)          2048      ['conv2d_751[0][0]']
#  atchNormalization)
#
#  add_190 (Add)               (None, 14, 14, 512)          0         ['conv2d_752[0][0]',
#                                                                      'batch_normalization_627[0][0
#                                                                     ]']
#
#  activation_660 (Activation  (None, 14, 14, 512)          0         ['add_190[0][0]']
#  )
#
#  conv2d_753 (Conv2D)         (None, 14, 14, 128)          65664     ['activation_660[0][0]']
#
#  batch_normalization_628 (B  (None, 14, 14, 128)          512       ['conv2d_753[0][0]']
#  atchNormalization)
#
#  activation_661 (Activation  (None, 14, 14, 128)          0         ['batch_normalization_628[0][0
#  )                                                                  ]']
#
#  conv2d_754 (Conv2D)         (None, 14, 14, 128)          147584    ['activation_661[0][0]']
#
#  batch_normalization_629 (B  (None, 14, 14, 128)          512       ['conv2d_754[0][0]']
#  atchNormalization)
#
#  activation_662 (Activation  (None, 14, 14, 128)          0         ['batch_normalization_629[0][0
#  )                                                                  ]']
#
#  conv2d_755 (Conv2D)         (None, 14, 14, 512)          66048     ['activation_662[0][0]']
#
#  conv2d_756 (Conv2D)         (None, 14, 14, 512)          262656    ['activation_660[0][0]']
#
#  batch_normalization_630 (B  (None, 14, 14, 512)          2048      ['conv2d_755[0][0]']
#  atchNormalization)
#
#  add_191 (Add)               (None, 14, 14, 512)          0         ['conv2d_756[0][0]',
#                                                                      'batch_normalization_630[0][0
#                                                                     ]']
#
#  activation_663 (Activation  (None, 14, 14, 512)          0         ['add_191[0][0]']
#  )
#
#  conv2d_757 (Conv2D)         (None, 14, 14, 256)          131328    ['activation_663[0][0]']
#
#  batch_normalization_631 (B  (None, 14, 14, 256)          1024      ['conv2d_757[0][0]']
#  atchNormalization)
#
#  activation_664 (Activation  (None, 14, 14, 256)          0         ['batch_normalization_631[0][0
#  )                                                                  ]']
#
#  conv2d_758 (Conv2D)         (None, 7, 7, 256)            590080    ['activation_664[0][0]']
#
#  batch_normalization_632 (B  (None, 7, 7, 256)            1024      ['conv2d_758[0][0]']
#  atchNormalization)
#
#  activation_665 (Activation  (None, 7, 7, 256)            0         ['batch_normalization_632[0][0
#  )                                                                  ]']
#
#  conv2d_760 (Conv2D)         (None, 7, 7, 1024)           525312    ['activation_663[0][0]']
#
#  conv2d_759 (Conv2D)         (None, 7, 7, 1024)           263168    ['activation_665[0][0]']
#
#  batch_normalization_634 (B  (None, 7, 7, 1024)           4096      ['conv2d_760[0][0]']
#  atchNormalization)
#
#  batch_normalization_633 (B  (None, 7, 7, 1024)           4096      ['conv2d_759[0][0]']
#  atchNormalization)
#
#  add_192 (Add)               (None, 7, 7, 1024)           0         ['batch_normalization_634[0][0
#                                                                     ]',
#                                                                      'batch_normalization_633[0][0
#                                                                     ]']
#
#  activation_666 (Activation  (None, 7, 7, 1024)           0         ['add_192[0][0]']
#  )
#
#  conv2d_761 (Conv2D)         (None, 7, 7, 256)            262400    ['activation_666[0][0]']
#
#  batch_normalization_635 (B  (None, 7, 7, 256)            1024      ['conv2d_761[0][0]']
#  atchNormalization)
#
#  activation_667 (Activation  (None, 7, 7, 256)            0         ['batch_normalization_635[0][0
#  )                                                                  ]']
#
#  conv2d_762 (Conv2D)         (None, 7, 7, 256)            590080    ['activation_667[0][0]']
#
#  batch_normalization_636 (B  (None, 7, 7, 256)            1024      ['conv2d_762[0][0]']
#  atchNormalization)
#
#  activation_668 (Activation  (None, 7, 7, 256)            0         ['batch_normalization_636[0][0
#  )                                                                  ]']
#
#  conv2d_763 (Conv2D)         (None, 7, 7, 1024)           263168    ['activation_668[0][0]']
#
#  conv2d_764 (Conv2D)         (None, 7, 7, 1024)           1049600   ['activation_666[0][0]']
#
#  batch_normalization_637 (B  (None, 7, 7, 1024)           4096      ['conv2d_763[0][0]']
#  atchNormalization)
#
#  add_193 (Add)               (None, 7, 7, 1024)           0         ['conv2d_764[0][0]',
#                                                                      'batch_normalization_637[0][0
#                                                                     ]']
#
#  activation_669 (Activation  (None, 7, 7, 1024)           0         ['add_193[0][0]']
#  )
#
#  conv2d_765 (Conv2D)         (None, 7, 7, 256)            262400    ['activation_669[0][0]']
#
#  batch_normalization_638 (B  (None, 7, 7, 256)            1024      ['conv2d_765[0][0]']
#  atchNormalization)
#
#  activation_670 (Activation  (None, 7, 7, 256)            0         ['batch_normalization_638[0][0
#  )                                                                  ]']
#
#  conv2d_766 (Conv2D)         (None, 7, 7, 256)            590080    ['activation_670[0][0]']
#
#  batch_normalization_639 (B  (None, 7, 7, 256)            1024      ['conv2d_766[0][0]']
#  atchNormalization)
#
#  activation_671 (Activation  (None, 7, 7, 256)            0         ['batch_normalization_639[0][0
#  )                                                                  ]']
#
#  conv2d_767 (Conv2D)         (None, 7, 7, 1024)           263168    ['activation_671[0][0]']
#
#  conv2d_768 (Conv2D)         (None, 7, 7, 1024)           1049600   ['activation_669[0][0]']
#
#  batch_normalization_640 (B  (None, 7, 7, 1024)           4096      ['conv2d_767[0][0]']
#  atchNormalization)
#
#  add_194 (Add)               (None, 7, 7, 1024)           0         ['conv2d_768[0][0]',
#                                                                      'batch_normalization_640[0][0
#                                                                     ]']
#
#  activation_672 (Activation  (None, 7, 7, 1024)           0         ['add_194[0][0]']
#  )
#
#  conv2d_769 (Conv2D)         (None, 7, 7, 256)            262400    ['activation_672[0][0]']
#
#  batch_normalization_641 (B  (None, 7, 7, 256)            1024      ['conv2d_769[0][0]']
#  atchNormalization)
#
#  activation_673 (Activation  (None, 7, 7, 256)            0         ['batch_normalization_641[0][0
#  )                                                                  ]']
#
#  conv2d_770 (Conv2D)         (None, 7, 7, 256)            590080    ['activation_673[0][0]']
#
#  batch_normalization_642 (B  (None, 7, 7, 256)            1024      ['conv2d_770[0][0]']
#  atchNormalization)
#
#  activation_674 (Activation  (None, 7, 7, 256)            0         ['batch_normalization_642[0][0
#  )                                                                  ]']
#
#  conv2d_771 (Conv2D)         (None, 7, 7, 1024)           263168    ['activation_674[0][0]']
#
#  conv2d_772 (Conv2D)         (None, 7, 7, 1024)           1049600   ['activation_672[0][0]']
#
#  batch_normalization_643 (B  (None, 7, 7, 1024)           4096      ['conv2d_771[0][0]']
#  atchNormalization)
#
#  add_195 (Add)               (None, 7, 7, 1024)           0         ['conv2d_772[0][0]',
#                                                                      'batch_normalization_643[0][0
#                                                                     ]']
#
#  activation_675 (Activation  (None, 7, 7, 1024)           0         ['add_195[0][0]']
#  )
#
#  conv2d_773 (Conv2D)         (None, 7, 7, 256)            262400    ['activation_675[0][0]']
#
#  batch_normalization_644 (B  (None, 7, 7, 256)            1024      ['conv2d_773[0][0]']
#  atchNormalization)
#
#  activation_676 (Activation  (None, 7, 7, 256)            0         ['batch_normalization_644[0][0
#  )                                                                  ]']
#
#  conv2d_774 (Conv2D)         (None, 7, 7, 256)            590080    ['activation_676[0][0]']
# ...
#
#  activation_766 (Activation  (None, 7, 7, 256)            0         ['batch_normalization_734[0][0
#  )                                                                  ]']
#
#  conv2d_894 (Conv2D)         (None, 7, 7, 256)            590080    ['activation_766[0][0]']
#
#  batch_normalization_735 (B  (None, 7, 7, 256)            1024      ['conv2d_894[0][0]']
#  atchNormalization)
#
#  activation_767 (Activation  (None, 7, 7, 256)            0         ['batch_normalization_735[0][0
#  )                                                                  ]']
#
#  conv2d_895 (Conv2D)         (None, 7, 7, 1024)           263168    ['activation_767[0][0]']
#
#  conv2d_896 (Conv2D)         (None, 7, 7, 1024)           1049600   ['activation_765[0][0]']
#
#  batch_normalization_736 (B  (None, 7, 7, 1024)           4096      ['conv2d_895[0][0]']
#  atchNormalization)
#
#  add_226 (Add)               (None, 7, 7, 1024)           0         ['conv2d_896[0][0]',
#                                                                      'batch_normalization_736[0][0
#                                                                     ]']
#
#  activation_768 (Activation  (None, 7, 7, 1024)           0         ['add_226[0][0]']
#  )
#
#  conv2d_897 (Conv2D)         (None, 7, 7, 256)            262400    ['activation_768[0][0]']
#
#  batch_normalization_737 (B  (None, 7, 7, 256)            1024      ['conv2d_897[0][0]']
#  atchNormalization)
#
#  activation_769 (Activation  (None, 7, 7, 256)            0         ['batch_normalization_737[0][0
#  )                                                                  ]']
#
#  conv2d_898 (Conv2D)         (None, 7, 7, 256)            590080    ['activation_769[0][0]']
#
#  batch_normalization_738 (B  (None, 7, 7, 256)            1024      ['conv2d_898[0][0]']
#  atchNormalization)
#
#  activation_770 (Activation  (None, 7, 7, 256)            0         ['batch_normalization_738[0][0
#  )                                                                  ]']
#
#  conv2d_899 (Conv2D)         (None, 7, 7, 1024)           263168    ['activation_770[0][0]']
#
#  conv2d_900 (Conv2D)         (None, 7, 7, 1024)           1049600   ['activation_768[0][0]']
#
#  batch_normalization_739 (B  (None, 7, 7, 1024)           4096      ['conv2d_899[0][0]']
#  atchNormalization)
#
#  add_227 (Add)               (None, 7, 7, 1024)           0         ['conv2d_900[0][0]',
#                                                                      'batch_normalization_739[0][0
#                                                                     ]']
#
#  activation_771 (Activation  (None, 7, 7, 1024)           0         ['add_227[0][0]']
#  )
#
#  conv2d_901 (Conv2D)         (None, 7, 7, 512)            524800    ['activation_771[0][0]']
#
#  batch_normalization_740 (B  (None, 7, 7, 512)            2048      ['conv2d_901[0][0]']
#  atchNormalization)
#
#  activation_772 (Activation  (None, 7, 7, 512)            0         ['batch_normalization_740[0][0
#  )                                                                  ]']
#
#  conv2d_902 (Conv2D)         (None, 4, 4, 512)            2359808   ['activation_772[0][0]']
#
#  batch_normalization_741 (B  (None, 4, 4, 512)            2048      ['conv2d_902[0][0]']
#  atchNormalization)
#
#  activation_773 (Activation  (None, 4, 4, 512)            0         ['batch_normalization_741[0][0
#  )                                                                  ]']
#
#  conv2d_904 (Conv2D)         (None, 4, 4, 2048)           2099200   ['activation_771[0][0]']
#
#  conv2d_903 (Conv2D)         (None, 4, 4, 2048)           1050624   ['activation_773[0][0]']
#
#  batch_normalization_743 (B  (None, 4, 4, 2048)           8192      ['conv2d_904[0][0]']
#  atchNormalization)
#
#  batch_normalization_742 (B  (None, 4, 4, 2048)           8192      ['conv2d_903[0][0]']
#  atchNormalization)
#
#  add_228 (Add)               (None, 4, 4, 2048)           0         ['batch_normalization_743[0][0
#                                                                     ]',
#                                                                      'batch_normalization_742[0][0
#                                                                     ]']
#
#  activation_774 (Activation  (None, 4, 4, 2048)           0         ['add_228[0][0]']
#  )
#
#  conv2d_905 (Conv2D)         (None, 4, 4, 512)            1049088   ['activation_774[0][0]']
#
#  batch_normalization_744 (B  (None, 4, 4, 512)            2048      ['conv2d_905[0][0]']
#  atchNormalization)
#
#  activation_775 (Activation  (None, 4, 4, 512)            0         ['batch_normalization_744[0][0
#  )                                                                  ]']
#
#  conv2d_906 (Conv2D)         (None, 4, 4, 512)            2359808   ['activation_775[0][0]']
#
#  batch_normalization_745 (B  (None, 4, 4, 512)            2048      ['conv2d_906[0][0]']
#  atchNormalization)
#
#  activation_776 (Activation  (None, 4, 4, 512)            0         ['batch_normalization_745[0][0
#  )                                                                  ]']
#
#  conv2d_907 (Conv2D)         (None, 4, 4, 2048)           1050624   ['activation_776[0][0]']
#
#  conv2d_908 (Conv2D)         (None, 4, 4, 2048)           4196352   ['activation_774[0][0]']
#
#  batch_normalization_746 (B  (None, 4, 4, 2048)           8192      ['conv2d_907[0][0]']
#  atchNormalization)
#
#  add_229 (Add)               (None, 4, 4, 2048)           0         ['conv2d_908[0][0]',
#                                                                      'batch_normalization_746[0][0
#                                                                     ]']
#
#  activation_777 (Activation  (None, 4, 4, 2048)           0         ['add_229[0][0]']
#  )
#
#  conv2d_909 (Conv2D)         (None, 4, 4, 512)            1049088   ['activation_777[0][0]']
#
#  batch_normalization_747 (B  (None, 4, 4, 512)            2048      ['conv2d_909[0][0]']
#  atchNormalization)
#
#  activation_778 (Activation  (None, 4, 4, 512)            0         ['batch_normalization_747[0][0
#  )                                                                  ]']
#
#  conv2d_910 (Conv2D)         (None, 4, 4, 512)            2359808   ['activation_778[0][0]']
#
#  batch_normalization_748 (B  (None, 4, 4, 512)            2048      ['conv2d_910[0][0]']
#  atchNormalization)
#
#  activation_779 (Activation  (None, 4, 4, 512)            0         ['batch_normalization_748[0][0
#  )                                                                  ]']
#
#  conv2d_911 (Conv2D)         (None, 4, 4, 2048)           1050624   ['activation_779[0][0]']
#
#  conv2d_912 (Conv2D)         (None, 4, 4, 2048)           4196352   ['activation_777[0][0]']
#
#  batch_normalization_749 (B  (None, 4, 4, 2048)           8192      ['conv2d_911[0][0]']
#  atchNormalization)
#
#  add_230 (Add)               (None, 4, 4, 2048)           0         ['conv2d_912[0][0]',
#                                                                      'batch_normalization_749[0][0
#                                                                     ]']
#
#  activation_780 (Activation  (None, 4, 4, 2048)           0         ['add_230[0][0]']
#  )
#
#  global_average_pooling2d_7  (None, 2048)                 0         ['activation_780[0][0]']
#   (GlobalAveragePooling2D)
#
#  flatten_7 (Flatten)         (None, 2048)                 0         ['global_average_pooling2d_7[0
#                                                                     ][0]']
#
#  dense_7 (Dense)             (None, 1000)                 2049000   ['flatten_7[0][0]']
#
# ==================================================================================================
# Total params: 107518824 (410.15 MB)
# Trainable params: 107367400 (409.57 MB)
# Non-trainable params: 151424 (591.50 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# # 6. Train ResNet50 on CIFAR10

# %%
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical

# Load CIFAR10 dataset
(cifar_X_train, cifar_y_train), (cifar_X_test, cifar_y_test) = cifar10.load_data()

# Normalizing between 0 and 1
cifar_X_train = cifar_X_train / 255.0
cifar_X_test = cifar_X_test / 255.0
#plt.imshow(x_train[0])


# Find num_of_classes and converting to one-hot
num_classes = len(np.unique(cifar_y_train))
cifar_Y_train = to_categorical(cifar_y_train, num_classes)
cifar_Y_test = to_categorical(cifar_y_test, num_classes)

# Split to validation set from train set
cifar_X_train, cifar_X_val = cifar_X_train[5000:, ...], cifar_X_train[:5000, ...]
cifar_Y_train, cifar_Y_val = cifar_Y_train[5000:, ...], cifar_Y_train[:5000, ...]

print(f"X_train.shape: {cifar_X_train.shape}")
print(f"Y_train.shape: {cifar_Y_train.shape}")
print(f"X_val.shape: {cifar_X_val.shape}")
print(f"Y_val.shape: {cifar_Y_val.shape}")
print(f"X_test.shape: {cifar_X_test.shape}")
print(f"Y_test.shape: {cifar_Y_test.shape}")
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
#   8503296/170498071 [>.............................] - ETA: 1:39
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[71], line 5
#       2 from tensorflow.keras.utils import to_categorical
#       4 # Load CIFAR10 dataset
# ----> 5 (cifar_X_train, cifar_y_train), (cifar_X_test, cifar_y_test) = cifar10.load_data()
#       7 # Normalizing between 0 and 1
#       8 cifar_X_train = cifar_X_train / 255.0
#
# File ~/miniconda3/envs/huflit_teaching/lib/python3.9/site-packages/keras/src/datasets/cifar10.py:81, in load_data()
#      79 dirname = "cifar-10-batches-py"
#      80 origin = "https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz"
# ---> 81 path = get_file(
#      82     dirname,
#      83     origin=origin,
#      84     untar=True,
#      85     file_hash=(  # noqa: E501
#      86         "6d958be074577803d12ecdefd02955f39262c83c16fe9348329d7fe0b5c001ce"
#      87     ),
#      88 )
#      90 num_train_samples = 50000
#      92 x_train = np.empty((num_train_samples, 3, 32, 32), dtype="uint8")
#
# File ~/miniconda3/envs/huflit_teaching/lib/python3.9/site-packages/keras/src/utils/data_utils.py:347, in get_file(fname, origin, untar, md5_hash, file_hash, cache_subdir, hash_algorithm, extract, archive_format, cache_dir)
#     345 try:
#     346     try:
# --> 347         urlretrieve(origin, fpath, DLProgbar())
#     348     except urllib.error.HTTPError as e:
#     349         raise Exception(error_msg.format(origin, e.code, e.msg))
#
# File ~/miniconda3/envs/huflit_teaching/lib/python3.9/site-packages/keras/src/utils/data_utils.py:87, in urlretrieve(url, filename, reporthook, data)
#      85 response = urlopen(url, data)
#      86 with open(filename, "wb") as fd:
# ---> 87     for chunk in chunk_read(response, reporthook=reporthook):
#      88         fd.write(chunk)
#
# File ~/miniconda3/envs/huflit_teaching/lib/python3.9/site-packages/keras/src/utils/data_utils.py:76, in urlretrieve.<locals>.chunk_read(response, chunk_size, reporthook)
#      74 count = 0
#      75 while True:
# ---> 76     chunk = response.read(chunk_size)
#      77     count += 1
#      78     if reporthook is not None:
#
# File ~/miniconda3/envs/huflit_teaching/lib/python3.9/http/client.py:463, in HTTPResponse.read(self, amt)
#     460 if amt is not None:
#     461     # Amount is given, implement using readinto
#     462     b = bytearray(amt)
# --> 463     n = self.readinto(b)
#     464     return memoryview(b)[:n].tobytes()
#     465 else:
#     466     # Amount is not given (unbounded read) so we must check self.length
#     467     # and self.chunked
#
# File ~/miniconda3/envs/huflit_teaching/lib/python3.9/http/client.py:507, in HTTPResponse.readinto(self, b)
#     502         b = memoryview(b)[0:self.length]
#     504 # we do not use _safe_read() here because this may be a .will_close
#     505 # connection, and the user is reading more bytes than will be provided
#     506 # (for example, reading in 1k chunks)
# --> 507 n = self.fp.readinto(b)
#     508 if not n and b:
#     509     # Ideally, we would raise IncompleteRead if the content-length
#     510     # wasn't satisfied, but it might break compatibility.
#     511     self._close_conn()
#
# File ~/miniconda3/envs/huflit_teaching/lib/python3.9/socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# File ~/miniconda3/envs/huflit_teaching/lib/python3.9/ssl.py:1275, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1271     if flags != 0:
#    1272         raise ValueError(
#    1273           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1274           self.__class__)
# -> 1275     return self.read(nbytes, buffer)
#    1276 else:
#    1277     return super().recv_into(buffer, nbytes, flags)
#
# File ~/miniconda3/envs/huflit_teaching/lib/python3.9/ssl.py:1133, in SSLSocket.read(self, len, buffer)
#    1131 try:
#    1132     if buffer is not None:
# -> 1133         return self._sslobj.read(len, buffer)
#    1134     else:
#    1135         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

# ResNet50
resnet50_cifar = ResNet(cifar_X_train.shape[1:], num_classes,
                 stages=[3,4,6,3], filters=[64,256,512,1024,2048])

resnet50_cifar.compile(optimizer='adam',
                     loss='categorical_crossentropy',
                     metrics=['accuracy'])

checkpointer = ModelCheckpoint(filepath='cifar_resnet.weights.best.hdf5',
                               verbose=1,
                               save_best_only=True)

callbacks = [checkpointer]

hist = resnet50_cifar.fit(cifar_X_train, cifar_Y_train,
                        validation_data=(cifar_X_val, cifar_Y_val),
                        batch_size=1000, epochs=30,
                        callbacks=callbacks,
                        verbose=1, shuffle=True)

# %%
import matplotlib.pyplot as plt

train_loss, val_loss = hist.history['loss'], hist.history['val_loss']
train_acc, val_acc = hist.history['accuracy'], hist.history['val_accuracy']

# Create a figure with two axes
fig, axs = plt.subplots(figsize=(8,3), nrows=1, ncols=2)

# Plot loss on the left axis
num_epochs = np.arange(len(train_loss))
axs[0].plot(num_epochs, train_loss)
axs[0].plot(num_epochs, val_loss)
axs[0].set_ylabel('loss')
axs[0].set_xlabel('epoch')
axs[0].set_title('model loss on CIFAR10')
axs[0].legend(['train', 'validation'], loc='upper right')

axs[1].plot(num_epochs, train_acc)
axs[1].plot(num_epochs, val_acc)
axs[1].set_ylabel('acc')
axs[1].set_xlabel('epoch')
axs[1].set_title('model accuracy on CIFAR10')
axs[1].legend(['train', 'validation'], loc='upper right')

plt.tight_layout()
plt.show()

# %%
# Evaluate
resnet50_cifar.load_weights('./cifar_resnet.weights.best.hdf5')
score = resnet50_cifar.evaluate(cifar_X_test, cifar_Y_test, verbose=0)

print(f"Test accuracy: {score[1] * 100}%")
